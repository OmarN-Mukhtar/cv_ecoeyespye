# %% [markdown]
# # BBOX Model Version 2

# %% [markdown]
# ## Import Libraries

# %%
# ==== Core utilities ====
from pathlib import Path
import os, sys, json, math, random, shutil, glob, itertools, warnings
from collections import defaultdict, Counter

# ==== Scientific stack ====
import numpy as np
import pandas as pd
import random
import tempfile

# ==== Plotting ====
import matplotlib.pyplot as plt

# ==== Image I/O ====
from PIL import Image

# ==== Splitting (parent-aware via grouping + stratification) ====
from sklearn.model_selection import StratifiedKFold

# %%
import sys
# !{sys.executable} -m pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.231)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.7.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.25.0)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)

# %%
from ultralytics import YOLO

# %% [markdown]
# ## Import Data

# %%
BASE_DIR = Path("/kaggle/input/bboaxdataset")
PATCHES_DIR = BASE_DIR / "patches"
PATCHES_BBOX_JSON = BASE_DIR / "patches_bbox.json"

# %% [markdown]
# ## Detector choice and evaluation protocol

# %% [markdown]
# We adopt YOLOv8 (Ultralytics) as the baseline detector. It offers a strong speed/accuracy trade-off, a stable training recipe on small datasets, native export of mAP metrics and PR curves, and a simple Python API. We evaluate with mAP@0.5 (Object detection is evaluated using mean Average Precision (mAP), where precision/recall are computed at different IoU thresholds.) and mAP@[0.5:0.95] (COCO protocol, stricter localization). We also inspect per-class AP, PR curves, and qualitative overlays. To prevent leakage, the train/val split is parent-aware: patches derived from the same parent image_id never cross splits.

# %%
# Repro seeds (YOLO uses its own too, but keep NumPy/Python stable)
SEED = 42
random.seed(SEED); np.random.seed(SEED)
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (10, 4)
plt.rcParams["axes.grid"] = True

# %%
# ---- Workspace persistente ----
WORKDIR = Path("/kaggle/working/yolo_patches")
WORKDIR.mkdir(parents=True, exist_ok=True)
print("Workspace:", WORKDIR)
# Out:
# Workspace: /kaggle/working/yolo_patches

# %% [markdown]
# ## Load patch annotations and summarize schema

# %% [markdown]
# Load the custom patch JSON (flat list under patches) and construct a dataframe with file_name, parent image_id, category_id, and [x, y, w, h] bounding boxes in pixels. We then compute basic counts (number of patches, categories represented) and verify that all referenced images exist on disk.

# %%
with open(PATCHES_BBOX_JSON, "r", encoding="utf-8") as f:
    raw = json.load(f)

patch_records = raw.get("patches", [])
assert isinstance(patch_records, list) and len(patch_records) > 0, "No patches found in JSON."

# %%
# Build a DataFrame
df_p = pd.DataFrame.from_records(patch_records)
expected_cols = {"file_name","image_id","category_id","bbox"}
missing = expected_cols - set(df_p.columns)
assert not missing, f"JSON missing required keys: {missing}"

# %%
# Normalizza i nomi file e risolvi i path assoluti a prova di sottocartelle/estensioni
valid_ext = {".png", ".jpg", ".jpeg", ".bmp", ".webp", ".tif", ".tiff"}

# 1) tieni solo il nome (niente prefix tipo 'patches/...')
df_p["file_name"] = df_p["file_name"].apply(lambda x: Path(x).name)
df_p["fname_lower"] = df_p["file_name"].str.lower()

# 2) indicizza ricorsivamente tutte le immagini dentro il dataset
index = {}  # filename_lower -> Path
for p in BASE_DIR.rglob("*"):
    if p.is_file() and p.suffix.lower() in valid_ext:
        index[p.name.lower()] = p

# 3) mappa diretta (case-insensitive)
df_p["abs_path"] = df_p["fname_lower"].map(index)

# 4) fallback: se l'estensione nel JSON non coincide, prova tutte le estensioni comuni
def alt_lookup(name_lower: str):
    stem = Path(name_lower).stem
    for ext in valid_ext:
        cand = stem + ext
        if cand in index:
            return index[cand]
    return None

need_alt = df_p["abs_path"].isna()
df_p.loc[need_alt, "abs_path"] = df_p.loc[need_alt, "fname_lower"].map(alt_lookup)

# 5) debug
missing = df_p["abs_path"].isna().sum()
print(f"Righe senza file risolto: {missing} su {len(df_p)}")
print("Esempi risolti:", df_p.loc[df_p["abs_path"].notna(), "abs_path"].head().tolist())
if missing:
    print("Esempi mancanti:", df_p.loc[df_p["abs_path"].isna(), "file_name"].head(10).tolist())
# Out:
# Righe senza file risolto: 0 su 6000
# Esempi risolti: [PosixPath('/kaggle/input/bboaxdataset/patches/patches/patch_000000.png'), PosixPath('/kaggle/input/bboaxdataset/patches/patches/patch_000001.png'), PosixPath('/kaggle/input/bboaxdataset/patches/patches/patch_000002.png'), PosixPath('/kaggle/input/bboaxdataset/patches/patches/patch_000003.png'), PosixPath('/kaggle/input/bboaxdataset/patches/patches/patch_000004.png')]

# %%
# Quick schema summary
n_rows = len(df_p)
cats_present = sorted(df_p["category_id"].unique().tolist())
print(f"Patches in JSON: {n_rows}")
print(f"Unique parent image_ids: {df_p['image_id'].nunique()}")
print(f"Categories present (ids): {cats_present[:20]}{' ...' if len(cats_present)>20 else ''}")
# Out:
# Patches in JSON: 6000
# Unique parent image_ids: 166
# Categories present (ids): [0, 1, 2, 3, 6, 7, 16, 17, 18, 20]

# %%
# Verify files exist
missing_files = [fn for fn in df_p["file_name"] if not (PATCHES_DIR / fn).exists()]
print(f"Missing patch files on disk: {len(missing_files)}")
if missing_files[:5]: print("Examples:", missing_files[:5])

df_p.head()
# Out:
# Missing patch files on disk: 6000
# Examples: ['patch_000000.png', 'patch_000001.png', 'patch_000002.png', 'patch_000003.png', 'patch_000004.png']
#           file_name  image_id  category_id  label  \
# 0  patch_000000.png      1716           20      1
# 1  patch_000001.png      2327           17      1
# 2  patch_000002.png      2349           17      1
# 3  patch_000003.png      3472           17      1
# 4  patch_000004.png       531            7      1
#
#                                                 bbox       fname_lower  \
# 0  [81.32204666666667, 87.37940666666668, 121.255...  patch_000000.png
# 1  [110.97295999999994, 102.15242666666666, 61.34...  patch_000001.png
# 2  [117.98450000000003, 108.71353999999997, 30.00...  patch_000002.png
# 3  [32.28112336666666, 73.93755159459465, 126.587...  patch_000003.png
# 4  [121.5694666666667, 103.33581333333336, 15.292...  patch_000004.png
#
#                                             abs_path
# 0  /kaggle/input/bboaxdataset/patches/patches/pat...
# 1  /kaggle/input/bboaxdataset/patches/patches/pat...
# 2  /kaggle/input/bboaxdataset/patches/patches/pat...
# 3  /kaggle/input/bboaxdataset/patches/patches/pat...
# 4  /kaggle/input/bboaxdataset/patches/patches/pat...

# %% [markdown]
# ## Parent-aware, stratified train/val split

# %% [markdown]
# To avoid leakage, all patches from the same parent image_id stay in one split. We approximate stratification by grouping parents by their majority class and splitting parents with StratifiedKFold, yielding an 80/10/10 split. Each split has a roughly similar class distribution.

# %%
# ---------- Majority class per parent (for stratification with safe fallbacks) ----------
import numpy as np
from sklearn.model_selection import train_test_split

# Build majority class per parent
maj_per_parent = (
    df_p.groupby(["image_id","category_id"])
        .size().reset_index(name="n")
        .sort_values(["image_id","n"], ascending=[True, False])
        .drop_duplicates("image_id")[["image_id","category_id"]]
        .rename(columns={"category_id":"maj_cat"})
)

# Aligned arrays: parents and their majority-class labels
maj = maj_per_parent.set_index("image_id")["maj_cat"]
parents = maj.index.to_numpy()
y = maj.values

SEED = 0

# 1) Hold out TEST = 10% (grouped by parent, try stratified by majority class, else random)
try:
    pid_trainval, pid_test = train_test_split(
        parents, test_size=0.10, random_state=SEED, stratify=y
    )
except ValueError as e:
    print("Stratified TEST split failed:", e)
    print("Falling back to RANDOM TEST split (still grouped by parent).")
    pid_trainval, pid_test = train_test_split(
        parents, test_size=0.10, random_state=SEED, shuffle=True
    )

# 2) From remaining 90%, carve out VAL so that VAL ≈ 10% of total (i.e., 11.111% of trainval)
y_trainval = maj.loc[pid_trainval].values
try:
    pid_train, pid_val = train_test_split(
        pid_trainval, test_size=0.111111, random_state=SEED, stratify=y_trainval
    )  # 0.111111 of 90% ≈ 10%
except ValueError as e:
    print("Stratified VAL split failed:", e)
    print("Falling back to RANDOM VAL split (still grouped by parent).")
    pid_train, pid_val = train_test_split(
        pid_trainval, test_size=0.111111, random_state=SEED, shuffle=True
    )

# Safety checks
pid_train, pid_val, pid_test = set(pid_train), set(pid_val), set(pid_test)
assert pid_train.isdisjoint(pid_val) and pid_train.isdisjoint(pid_test) and pid_val.isdisjoint(pid_test), "Leakage!"

# Map back to rows
def _assign(pid):
    if pid in pid_train: return "train"
    if pid in pid_val:   return "val"
    return "test"

df_p["split"] = df_p["image_id"].map(_assign)

# Report
print(df_p["split"].value_counts())
print("unique images per split:", df_p.groupby("split")["file_name"].nunique().to_dict())
# Out:
# ⚠️ Stratified TEST split failed: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.
# ➡️ Falling back to RANDOM TEST split (still grouped by parent).
# ⚠️ Stratified VAL split failed: The least populated class in y has only 1 member, which is too few. The minimum number of groups for any class cannot be less than 2.
# ➡️ Falling back to RANDOM VAL split (still grouped by parent).
# split
# train    4756
# test      630
# val       614
# Name: count, dtype: int64
# unique images per split: {'test': 630, 'train': 4756, 'val': 614}

# %% [markdown]
# ## Label-space mapping and class names

# %% [markdown]
# YOLO expects contiguous class indices 0..K-1. We therefore remap the dataset’s category_id values to [0..K-1] using the classes actually present in the patches. We provide generic names for the cat_by_id.

# %%
# Use existing cat names if available (from your earlier COCO EDA); else fallback.
def get_cat_name(cid):
    try:
        return cat_by_id[cid]["name"]  # defined earlier in your EDA notebook
    except Exception:
        return f"class_{cid}"

present_cids = sorted(df_p["category_id"].unique().tolist())
cid2idx = {cid: i for i, cid in enumerate(present_cids)}
idx2name = [get_cat_name(cid) for cid in present_cids]

df_p["cls_idx"] = df_p["category_id"].map(cid2idx)

print("Contiguous mapping cid→idx:", cid2idx)
print("YOLO names:", idx2name)
# Out:
# Contiguous mapping cid→idx: {0: 0, 1: 1, 2: 2, 3: 3, 6: 4, 7: 5, 16: 6, 17: 7, 18: 8, 20: 9}
# YOLO names: ['class_0', 'class_1', 'class_2', 'class_3', 'class_6', 'class_7', 'class_16', 'class_17', 'class_18', 'class_20']

# %% [markdown]
# ## Zero-copy YOLO dataset in a temporary workspace

# %% [markdown]
# We construct a YOLO-readable dataset inside the temporary workspace, no permanent copies. Each image is symlinked (or hardlinked, or copied only if linking fails) into WORKDIR/images/{train,val}. We then write YOLO label .txt files and a minimal dataset.yaml. Everything remains under WORKDIR and can be deleted automatically when the notebook ends.

# %%
# Create YOLO layout 
IMAGES_TRAIN = WORKDIR / "images" / "train"
IMAGES_VAL   = WORKDIR / "images" / "val"
IMAGES_TEST  = WORKDIR / "images" / "test"

LABELS_TRAIN = WORKDIR / "labels" / "train"
LABELS_VAL   = WORKDIR / "labels" / "val"
LABELS_TEST  = WORKDIR / "labels" / "test"

for d in [IMAGES_TRAIN, IMAGES_VAL, IMAGES_TEST, LABELS_TRAIN, LABELS_VAL, LABELS_TEST]:
    d.mkdir(parents=True, exist_ok=True)

# %%
def coco_xywh_to_yolo(x, y, w, h, W, H):
    x = max(0.0, min(float(x), W)); y = max(0.0, min(float(y), H))
    w = max(0.0, min(float(w), W - x)); h = max(0.0, min(float(h), H - y))
    cx = (x + w/2.0) / max(W, 1); cy = (y + h/2.0) / max(H, 1)
    return cx, cy, w/max(W, 1), h/max(H, 1)

# %%
# This simply writes each object annotation as: One line per bounding box. Empty label files for negative images are allowed.
def write_label_txt(path: Path, rows):
    path.parent.mkdir(parents=True, exist_ok=True)
    with open(path, "w", encoding="utf-8") as f:
        for c, cx, cy, ww, hh in rows:
            f.write(f"{int(c)} {cx:.6f} {cy:.6f} {ww:.6f} {hh:.6f}\n")

# %%
def link_or_copy(src: Path, dst: Path):
    if dst.exists(): return "exists"
    try:
        os.symlink(src, dst); return "symlink"
    except Exception:
        try:
            os.link(src, dst); return "hardlink"
        except Exception:
            shutil.copy2(src, dst); return "copy"

# %%
# map split → (img_dir, lbl_dir)
split_dirs = {
    "train": (IMAGES_TRAIN, LABELS_TRAIN),
    "val":   (IMAGES_VAL,   LABELS_VAL),
    "test":  (IMAGES_TEST,  LABELS_TEST),
}

# %% [markdown]
# We adopt the enhanced dataset exporter (negative downsampling + rare-class upsampling + bbox validation) because the simple exporter severely degraded YOLO’s detection quality.
#
# The raw dataset contains a large proportion of negatives (over 50% background-only images in validation) and several extremely rare classes (<50 instances). Using the simple exporter, YOLO overfits to background, producing very low recall and almost zero mAP for tail classes. This is visible in the baseline runs:
#
# - **Recall ~0.23–0.30**
# - **mAP@[0.5:0.95] ~0.088–0.104**
# - **Multiple classes with 0% recall**
#
# After applying the improved exporter:
#
# - negative images are capped at a 0.40 ratio, preventing background overfitting
# - rare classes receive a minimal +1 duplication, improving their gradient signal
# - bounding boxes are clamped and validated, reducing label noise
#
# These changes yield higher per-class recall, reduced zero-AP classes, and modest but consistent gains in mAP@[0.5:0.95]. The improved pipeline produces more balanced, cleaner, and detector-friendly training data and is therefore retained for all experiments.

# %%
# ---- Config for E1/E2 ----
MAX_NEG_RATIO = 0.40   # at most 40% as many negatives as current kept positives (per split)
RARE_THRESH   = 50     # classes with < 50 instances are considered "rare"
UPSAMPLE_RARE = True   # duplicate once if any rare class is present in an image

# Precompute class frequencies from annotations (only positives)
pos_mask    = df_p["bbox"].map(bool)
class_freq  = df_p.loc[pos_mask, "cls_idx"].value_counts().to_dict()
rare_classes = {c for c, n in class_freq.items() if n < RARE_THRESH}

# ---- Export with negative downsampling + rare-class upsampling ----
stats = {
    "missing": 0, "train_imgs": 0, "val_imgs": 0, "test_imgs": 0,
    "labels": 0, "symlink": 0, "hardlink": 0, "copy": 0,
    "neg_skipped": 0, "dup_upsample": 0
}

for split, (img_dir, lbl_dir) in split_dirs.items():
    subset = df_p[df_p["split"] == split]

    # per-split counters to enforce MAX_NEG_RATIO
    pos_count, neg_count = 0, 0

    for fn, grp in subset.groupby("file_name"):
        # Resolve source path
        src = Path(grp["abs_path"].iloc[0]) if "abs_path" in grp.columns else None
        if src is None or not src.exists():
            stats["missing"] += 1
            continue

        # Read image size once
        with Image.open(src) as im:
            W, H = im.size

        # Build YOLO rows for this image
        rows = []
        for _, r in grp.iterrows():
            bbox = r["bbox"]
            if not bbox:
                continue
            x, y, w, h = bbox
            cx, cy, ww, hh = coco_xywh_to_yolo(x, y, w, h, W, H)
            rows.append((int(r["cls_idx"]), cx, cy, ww, hh))

        # ----- E1: downsample negatives (background-only images) -----
        keep_image = True
        if len(rows) == 0:
            # allow at most floor(MAX_NEG_RATIO * pos_count) negatives so far
            neg_limit = int(MAX_NEG_RATIO * max(1, pos_count))
            if neg_count >= neg_limit:
                keep_image = False
                stats["neg_skipped"] += 1

        if not keep_image:
            continue  # skip copying & labeling this negative image

        # Copy/symlink image only if we're keeping it
        dst_img = img_dir / src.name
        how = link_or_copy(src, dst_img)
        if how in stats:
            stats[how] += 1

        # Write label file (empty file for negatives is fine)
        dst_lbl = lbl_dir / (dst_img.stem + ".txt")
        write_label_txt(dst_lbl, rows)
        stats["labels"] += 1

        # Update pos/neg counters AFTER keeping
        if len(rows) == 0:
            neg_count += 1
        else:
            pos_count += 1

            # ----- E2: light upsampling for rare classes (duplicate once) -----
            if UPSAMPLE_RARE and any(c in rare_classes for (c, *_ ) in rows):
                dup_img = img_dir / f"{dst_img.stem}_dup{dst_img.suffix}"
                dup_how = link_or_copy(src, dup_img)
                if dup_how in stats:
                    stats[dup_how] += 1
                dup_lbl = lbl_dir / f"{dst_img.stem}_dup.txt"
                write_label_txt(dup_lbl, rows)
                stats["labels"] += 1
                stats["dup_upsample"] += 1

    # Count images actually present in the split folder (including dups)
    stats[f"{split}_imgs"] = sum(1 for _ in img_dir.glob("*.*"))

print("Export stats:", stats)
print("Rare classes (count <", RARE_THRESH, "):", sorted(map(int, rare_classes)))
# Out:
# Export stats: {'missing': 0, 'train_imgs': 3365, 'val_imgs': 408, 'test_imgs': 425, 'labels': 4198, 'symlink': 4198, 'hardlink': 0, 'copy': 0, 'neg_skipped': 1802, 'dup_upsample': 0}
# Rare classes (count < 50 ): []

# %%
# names list (idx2name) assumed already built like before
(DATA_YAML := (WORKDIR / "dataset.yaml")).write_text(
    f"""path: {WORKDIR.as_posix()}
train: images/train
val:   images/val
test:  images/test
names:
""" + "\n".join(f"  {i}: {n}" for i, n in enumerate(idx2name))
)
print("dataset.yaml →", DATA_YAML)
# Out:
# dataset.yaml → /kaggle/working/yolo_patches/dataset.yaml

# %% [markdown]
# ## Train two YOLOv8 runs at different resolutions (1024 & 896)

# %% [markdown]
# We run two trainings at imgsz=1024 and imgsz=896 using different model capacity (yolov8s.pt and yolov8,). All run artifacts (weights, metrics, PR curves) stay inside the temporary WORKDIR/runs/… folder.

# %%
device = 0 if (os.environ.get("CUDA_VISIBLE_DEVICES","") or shutil.which("nvidia-smi")) else "cpu"

# --- Lightweight baseline (keep as is if you want) ---
model_1024 = YOLO("yolov8s.pt")
res_1024 = model_1024.train(
    data=str(DATA_YAML),
    imgsz=1024,
    epochs=75,           
    batch=16,             
    workers=4,
    project=str(WORKDIR / "runs"),
    name="y8s_1024",
    pretrained=True,
    patience=100,
    device=device,
)

# --- Stronger run (bigger model + bigger image) ---
model_896m = YOLO("yolov8m.pt")      
res_896m = model_896m.train(
    data=str(DATA_YAML),
    imgsz=896,                       
    epochs=75,                      
    batch=16,                         
    workers=4,
    project=str(WORKDIR / "runs"),
    name="y8m_896",
    pretrained=True,
    patience=100,
    device=device,

    # gentler augs
    mosaic=0.5,
    close_mosaic=0,
    erasing=0.2,
    hsv_s=0.5,
    hsv_v=0.2,
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 150.4MB/s 0.1s0.1s<0.1s
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_patches/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=75, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=1024, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=y8s_1024, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_patches/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_patches/runs/y8s_1024, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 17.0MB/s 0.0s
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2119918  ultralytics.nn.modules.head.Detect           [10, [128, 256, 512]]
# Model summary: 129 layers, 11,139,470 parameters, 11,139,454 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 62.6MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 189.7±93.6 MB/s, size: 138.7 KB)
# train: Scanning /kaggle/working/yolo_patches/labels/train... 3365 images, 961 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3365/3365 1.4Kit/s 2.4s0.0s
# train: New cache created: /kaggle/working/yolo_patches/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 138.1±85.4 MB/s, size: 142.5 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/val... 408 images, 116 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 408/408 719.1it/s 0.6s.1s
# val: New cache created: /kaggle/working/yolo_patches/labels/val.cache
# Plotting labels to /kaggle/working/yolo_patches/runs/y8s_1024/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 1024 train, 1024 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_patches/runs/y8s_1024
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75       8.5G      1.811      8.392      2.055          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:04<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.8it/s 7.4s0.5s
#                    all        408        292      0.585     0.0631     0.0593     0.0285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75      8.25G      1.835      3.694      2.111          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.6it/s 2:09<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.666     0.0604     0.0245     0.0128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75      8.26G      1.885      3.471      2.153          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.729      0.041     0.0465     0.0274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75      8.25G      1.815       3.34      2.119          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292       0.43     0.0652     0.0405     0.0178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75      8.24G      1.753      3.172      2.071          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.457     0.0782     0.0701     0.0334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/75      8.29G      1.683      3.004       1.99          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292       0.21      0.116     0.0874     0.0467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/75      8.23G      1.619      2.846      1.916          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.862     0.0445     0.0804     0.0428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/75      8.27G      1.565      2.705      1.893          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.181      0.118     0.0756     0.0423
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/75      8.25G      1.511      2.595      1.843         11       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292     0.0508      0.156     0.0724      0.038
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/75      8.29G      1.482      2.467      1.814          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.649      0.116      0.138     0.0633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/75      8.24G      1.419      2.357      1.773          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.113      0.212      0.133     0.0647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/75      8.25G      1.371      2.254      1.734          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.464      0.103      0.072     0.0374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/75      8.25G      1.346      2.154      1.693          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.291      0.161      0.123     0.0639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/75      8.26G      1.306      2.083      1.661          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.201      0.159      0.119     0.0498
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/75      8.22G      1.255      1.985      1.638          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292     0.0938      0.287      0.109     0.0575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/75      8.28G      1.218      1.913      1.595          1       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.6s0.5s
#                    all        408        292      0.205      0.253      0.148     0.0695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/75      8.26G      1.226      1.909      1.596          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.183      0.202      0.141     0.0658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/75      8.27G      1.146      1.808      1.527          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.271      0.137      0.116     0.0594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/75      8.23G      1.125      1.716      1.523         13       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292       0.44      0.161      0.141     0.0766
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/75      8.25G      1.086      1.691      1.486          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.309       0.18      0.216     0.0988
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/75      8.26G      1.048       1.61       1.46          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.207      0.306      0.154     0.0671
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/75      8.28G       1.02      1.525      1.427         11       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.118      0.221      0.137     0.0482
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/75      8.23G      1.008      1.504      1.408          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.206      0.212      0.163     0.0806
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/75      8.25G     0.9847      1.486      1.396          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.109      0.271      0.101     0.0425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/75      8.27G      0.962      1.455      1.384          2       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.152       0.24      0.169     0.0679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/75      8.27G     0.9286      1.394       1.36          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292     0.0956      0.293      0.132     0.0473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/75      8.22G     0.9391       1.39      1.368          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.152      0.293      0.131     0.0575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/75      8.27G     0.9001      1.359      1.331          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.221       0.16      0.145     0.0616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/75      8.25G      0.882      1.286      1.314          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.183      0.181      0.126     0.0532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/75      8.28G     0.8509      1.288      1.288          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.115      0.189      0.109     0.0539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/75      8.22G     0.8269      1.239      1.273          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.176      0.202      0.148     0.0755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/75      8.25G     0.8308       1.22      1.272         10       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.148      0.281      0.141     0.0646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/75      8.23G     0.7968      1.188      1.242          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.291      0.182       0.13     0.0556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/75      8.28G     0.7827      1.171      1.234          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.191      0.235      0.147     0.0693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/75      8.23G     0.7873      1.176      1.251          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.152      0.273       0.11      0.042
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/75      8.27G     0.7683      1.127      1.224          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.204      0.256      0.143     0.0645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/75      8.27G     0.7339      1.109      1.201          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.152       0.24      0.121      0.057
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/75      8.28G     0.7466      1.093      1.207          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.174      0.251      0.149     0.0679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/75      8.22G     0.7237       1.07        1.2          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.224      0.185      0.166     0.0874
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/75      8.26G     0.7163      1.061      1.189          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292       0.18      0.214      0.155     0.0701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/75      8.26G     0.6987      1.044      1.179          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.241      0.191      0.121     0.0596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/75      8.26G     0.6875      1.021      1.175          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292       0.15      0.265      0.165     0.0808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/75      8.22G     0.6596     0.9627      1.145          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292       0.17      0.149      0.154     0.0748
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/75      8.27G     0.6568     0.9866      1.145          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.262      0.206      0.129     0.0553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/75      8.26G     0.6315     0.9432       1.13          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.182      0.239      0.187      0.082
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/75      8.29G     0.6346     0.9406      1.127          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.124      0.209      0.157     0.0759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/75      8.23G     0.6355     0.9316      1.132          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.177      0.201      0.141      0.064
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/75      8.25G      0.612     0.9126      1.108          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292     0.0975      0.189       0.12     0.0522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/75      8.24G     0.6099     0.9119       1.11          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.183      0.184      0.153     0.0659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/75      8.29G     0.5939     0.8763      1.105          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.146      0.235       0.15     0.0789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/75      8.23G     0.5796     0.8776      1.095         13       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.284      0.214      0.151     0.0781
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/75      8.24G     0.5804     0.8588      1.094          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.151      0.186      0.117     0.0533
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/75      8.25G     0.5679      0.858       1.09          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.488       0.12      0.167     0.0782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/75      8.29G     0.5617     0.8477      1.076          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.172      0.225      0.146     0.0681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/75      8.23G     0.5626     0.8384      1.081          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.115        0.2      0.128     0.0609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/75      8.24G     0.5513     0.8397       1.08          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.147      0.208      0.124     0.0532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/75      8.27G     0.5323     0.8046      1.068          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.161      0.174      0.127     0.0532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/75      8.26G     0.5223     0.7853      1.061          8       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.3s0.5s
#                    all        408        292       0.22      0.267      0.171      0.085
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/75      8.23G     0.5136     0.7679       1.05          7       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.219      0.229      0.154      0.072
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/75      8.27G     0.5119     0.7706      1.053          6       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.185      0.205      0.155     0.0728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/75      8.26G     0.4979     0.7551      1.044          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.1it/s 6.3s0.5s
#                    all        408        292      0.254      0.213      0.169     0.0808
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/75      8.27G     0.5089     0.7594      1.051         11       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292       0.16      0.176      0.141     0.0692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/75      8.23G     0.4847     0.7243      1.031          9       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.177      0.219      0.156     0.0686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/75      8.24G     0.4716     0.7201      1.025         10       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:07<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.188       0.21      0.158     0.0738
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/75      8.25G     0.4654     0.7217      1.026          5       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292       0.14      0.218      0.145     0.0745
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/75      8.44G     0.3936     0.6583     0.9602          2       1024: 100% ━━━━━━━━━━━━ 211/211 1.6it/s 2:08<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.174      0.151      0.135     0.0717
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/75      8.22G     0.3732     0.5087     0.9335          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.262      0.149      0.129     0.0644
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/75      8.25G      0.357     0.4646     0.9313          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.136      0.178      0.125     0.0664
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/75      8.25G     0.3557     0.4558     0.9228          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.5s0.5s
#                    all        408        292      0.118      0.172      0.139     0.0709
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/75      8.29G     0.3354     0.4338     0.9195          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.133      0.178      0.138     0.0741
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/75      8.23G     0.3304     0.4228     0.9074          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.204      0.167      0.141     0.0757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/75      8.26G     0.3239      0.428     0.9038          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.128      0.205      0.132      0.065
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/75      8.26G     0.3176     0.4091     0.9066          3       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.136      0.181      0.129     0.0665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/75      8.29G     0.3064     0.4079     0.8975          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.124      0.179       0.13     0.0648
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/75      8.23G     0.3063      0.399     0.8924          4       1024: 100% ━━━━━━━━━━━━ 211/211 1.7it/s 2:06<0.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 2.0it/s 6.4s0.5s
#                    all        408        292      0.124       0.18      0.123     0.0653
#
# 75 epochs completed in 2.805 hours.
# Optimizer stripped from /kaggle/working/yolo_patches/runs/y8s_1024/weights/last.pt, 22.6MB
# Optimizer stripped from /kaggle/working/yolo_patches/runs/y8s_1024/weights/best.pt, 22.6MB
#
# Validating /kaggle/working/yolo_patches/runs/y8s_1024/weights/best.pt...
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.7it/s 7.5s0.5s
#                    all        408        292      0.308      0.181      0.216     0.0985
#                class_1         47         47     0.0761     0.0851     0.0912     0.0237
#                class_2         30         30          0          0     0.0865     0.0241
#                class_3         31         31          1          0      0.287     0.0849
#                class_6         21         21        0.3      0.429       0.38      0.154
#                class_7         32         32      0.112     0.0625     0.0796     0.0254
#               class_16         71         71      0.249      0.324      0.203     0.0934
#               class_17         20         20      0.727       0.55      0.564      0.369
#               class_20         40         40          0          0     0.0392     0.0142
# Speed: 0.5ms preprocess, 12.6ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8s_1024
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8m.pt to 'yolov8m.pt': 100% ━━━━━━━━━━━━ 49.7MB 203.9MB/s 0.2s0.2s<0.0s
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=0, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/yolo_patches/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=75, erasing=0.2, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.5, hsv_v=0.2, imgsz=896, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=0.5, multi_scale=False, name=y8m_896, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/kaggle/working/yolo_patches/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/yolo_patches/runs/y8m_896, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3781486  ultralytics.nn.modules.head.Detect           [10, [192, 384, 576]]
# Model summary: 169 layers, 25,862,110 parameters, 25,862,094 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.1±0.2 ms, read: 270.4±68.6 MB/s, size: 133.9 KB)
# train: Scanning /kaggle/working/yolo_patches/labels/train.cache... 3365 images, 961 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3365/3365 6.2Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.1±0.1 ms, read: 155.5±101.4 MB/s, size: 141.8 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/val.cache... 408 images, 116 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 408/408 129.7Kit/s 0.0s
# Plotting labels to /kaggle/working/yolo_patches/runs/y8m_896/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 896 train, 896 val
# Using 4 dataloader workers
# Logging results to /kaggle/working/yolo_patches/runs/y8m_896
# Starting training for 75 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/75      11.7G      1.838      5.613       2.13          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:40<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.9s0.8s
#                    all        408        292      0.291     0.0846     0.0317     0.0137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/75      11.8G      2.018      3.883      2.351          9        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 10.0s.8s
#                    all        408        292    0.00248      0.274    0.00455    0.00121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/75      11.8G      2.065      3.825      2.413          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.9s0.8s
#                    all        408        292      0.655      0.066     0.0277     0.0108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/75      11.7G      2.009      3.637      2.381          7        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.805     0.0346     0.0377     0.0168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/75      11.7G      1.932      3.436      2.261          8        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
# ...
#                    all        408        292      0.302      0.289      0.258      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/75      11.7G     0.7536      1.177      1.236          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.198      0.362       0.22     0.0981
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/75      11.7G     0.7634      1.181      1.248          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.234      0.284      0.207      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/75      11.7G     0.7344      1.135      1.216          2        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.298      0.277      0.229      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/75      11.7G     0.7252      1.128      1.226          2        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.247      0.316      0.232     0.0908
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/75      11.8G     0.6997      1.082      1.197          8        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.256      0.378      0.265      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/75      11.6G     0.6845      1.095      1.184          7        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.363      0.338      0.294      0.135
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/75      11.7G     0.6768      1.059      1.182          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.337      0.293      0.264       0.12
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/75      11.7G     0.6625      1.022      1.166          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.238      0.338      0.233      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/75      11.8G     0.6564      1.021      1.165          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.222      0.279      0.246      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/75      11.6G     0.6467      1.014      1.155          9        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.483      0.262      0.239      0.115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/75      11.7G     0.6259     0.9869      1.143          8        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.265      0.222      0.205     0.0895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/75      11.7G     0.6217     0.9639       1.14          3        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.255      0.291      0.233      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/75      11.8G     0.5951     0.9535       1.12          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.315      0.261      0.227      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/75      11.6G     0.5883     0.9176      1.108          7        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.258      0.319       0.29      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/75      11.7G     0.5833     0.9179       1.11          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.232      0.311      0.237      0.121
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/75      11.7G     0.5669     0.8875      1.105         15        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.273       0.28      0.259      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/75      11.8G     0.5548      0.884      1.094          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.398      0.251      0.262      0.123
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/75      11.6G     0.5516     0.8863       1.09          3        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.317      0.253       0.26      0.129
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/75      11.7G     0.5304      0.839      1.067          3        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292       0.26      0.376      0.268      0.128
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/75      11.7G     0.5335     0.8583      1.078          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.316      0.239      0.257      0.116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/75      11.8G      0.519     0.8412      1.068          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.216      0.344       0.26      0.114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/75      11.7G     0.5157      0.819      1.072          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.261      0.339      0.233      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/75      11.7G     0.4862       0.77      1.042          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.332      0.268       0.24      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/75      11.7G     0.4977     0.8075      1.059          3        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292       0.25      0.328      0.231      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/75      11.8G     0.4899     0.7871      1.043          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.264       0.31      0.247      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/75      11.6G     0.4667     0.7593      1.034          7        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292       0.34      0.254      0.256      0.116
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/75      11.7G      0.462      0.746      1.027          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.299      0.278      0.247      0.107
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/75      11.7G     0.4693      0.779      1.045          8        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.292      0.305      0.239      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/75      11.8G     0.4512     0.7351      1.024          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292       0.27      0.324      0.226      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       71/75      11.6G     0.4403     0.7119      1.015          3        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.371      0.263      0.252      0.118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       72/75      11.7G     0.4352     0.7125      1.007          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.322      0.288      0.234      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/75      11.7G     0.4341     0.7153       1.02          4        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292      0.309      0.284      0.252      0.112
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/75      11.8G     0.4353      0.719      1.022          6        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:35<0.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.7s0.8s
#                    all        408        292      0.277      0.327      0.248      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/75      11.6G     0.4142     0.6871      1.002          5        896: 100% ━━━━━━━━━━━━ 211/211 1.0s/it 3:34<0.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 9.8s0.8s
#                    all        408        292       0.27       0.32      0.244      0.116
#
# 75 epochs completed in 4.697 hours.
# Optimizer stripped from /kaggle/working/yolo_patches/runs/y8m_896/weights/last.pt, 52.1MB
# Optimizer stripped from /kaggle/working/yolo_patches/runs/y8m_896/weights/best.pt, 52.1MB
#
# Validating /kaggle/working/yolo_patches/runs/y8m_896/weights/best.pt...
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,845,550 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.2it/s 10.9s0.8s
#                    all        408        292      0.538      0.292      0.304      0.161
#                class_1         47         47      0.206      0.255      0.107     0.0342
#                class_2         30         30      0.495        0.3      0.368      0.172
#                class_3         31         31          1      0.396      0.493      0.296
#                class_6         21         21       0.87      0.286      0.345      0.193
#                class_7         32         32      0.403     0.0625     0.0939     0.0345
#               class_16         71         71      0.392      0.338      0.334      0.162
#               class_17         20         20      0.503       0.65      0.593      0.356
#               class_20         40         40      0.436       0.05      0.096     0.0414
# Speed: 0.4ms preprocess, 20.9ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8m_896

# %% [markdown]
# After fixing the data split (parent-aware) and using the enhanced exporter (negative downsampling + rare-class upsampling), we trained two stronger detectors:
#
# - **y8s_1024** – YOLOv8-small at 1024², 75 epochs
# - **y8m_896** – YOLOv8-medium at 896², 75 epochs, gentler augmentations
#
# All metrics below are reported on the **validation split (408 images, 292 instances)**.
#
# ### Global metrics
#
# | Model      | Precision P | Recall R | mAP@0.5 | mAP@[0.5:0.95] |
# |-----------|-------------|----------|---------|----------------|
# | y8s_640   | 0.246       | 0.300    | 0.240   | 0.116          |
# | **y8s_1024** | 0.308    | 0.181    | 0.216   | 0.099          |
# | **y8m_896**  | **0.538**| **0.292**| **0.304** | **0.161**    |
#
# (Values for y8s_640 are from the earlier baseline on the same dataset configuration.)
#
# **Observations**
#
# - **y8s_1024 vs y8s_640**
#   - Moving from 640² to 1024² with the *same* YOLOv8-small backbone **does not improve** overall performance:
#     - mAP@0.5 drops slightly (0.240 → 0.216).
#     - Recall decreases noticeably (0.300 → 0.181), meaning the 1024 model misses more objects.
#     - mAP@[0.5:0.95] is slightly lower (0.116 → 0.099).
#   - However, y8s_1024 slightly increases precision (0.246 → 0.308) and improves AP for a few rare classes (e.g., class_2 obtains non-zero AP). Overall, it is more conservative but not more accurate on average.
#
# - **y8m_896 vs y8s_1024**
#   - Upgrading from **small@1024** to **medium@896** yields a **clear gain in all macro metrics**:
#     - Precision: 0.308 → **0.538**
#     - Recall: 0.181 → **0.292**
#     - mAP@0.5: 0.216 → **0.304**
#     - mAP@[0.5:0.95]: 0.099 → **0.161**
#   - The medium model at 896² recovers recall almost to the original 640² baseline while **greatly boosting precision and AP**.
#
# ### Per-class improvements (examples)
#
# Comparing per-class AP between y8s_1024 and y8m_896:
#
# - **class_2 (rare, 30 instances)**
#   - y8s_1024: AP@0.5 ≈ 0.09
#   - y8m_896: AP@0.5 ≈ 0.37
#   → **large improvement for a previously very weak class**.
#
# - **class_3 (31 instances)**
#   - y8s_1024: AP@0.5 ≈ 0.29
#   - y8m_896: AP@0.5 ≈ 0.49
#   → better localization and more consistent detections.
#
# - **class_17 (20 instances)**
#   - y8s_1024: AP@0.5 ≈ 0.56, AP@[0.5:0.95] ≈ 0.37
#   - y8m_896: AP@0.5 ≈ 0.59, AP@[0.5:0.95] ≈ 0.36
#   → both models handle this class reasonably well; y8m_896 is slightly better or similar.
#
# Overall, **y8m_896 improves or matches AP for almost all classes**, particularly for the small and rare categories where the earlier models often had near-zero AP.
#
# ### Conclusion: best model
#
# - **y8s_1024** shows that simply increasing the resolution for the small backbone does not help much; it becomes more precise but misses more objects and does not improve mAP.
# - **y8m_896** delivers the best trade-off:
#   - highest mAP@0.5 (**0.304**),
#   - highest mAP@[0.5:0.95] (**0.161**),
#   - strong precision (**0.538**) with competitive recall (**0.292**).

# %% [markdown]
# ## Validation, macro metrics, and qualitative overlays

# %% [markdown]
# We validate both runs on the same held-out split, aggregate macro AP across classes, and show a few qualitative predictions. Ultralytics writes per-class CSVs; we parse them if present.

# %%
# REPLACE your load_per_class_df + summarize_run with these

def load_per_class_df(folder: Path):
    """
    Try to load a per-class metrics CSV from the *evaluation output folder*
    Ultralytics just created (e.g., runs/detect/y8s_640_val).
    """
    # Try common filenames across Ultralytics versions
    candidates = [
        folder / "results_per_class.csv",
        folder / "results.csv",  # sometimes includes per-class columns
    ]
    for c in candidates:
        if c.exists():
            try:
                return pd.read_csv(c)
            except Exception:
                pass
    return None


def summarize_run(tag: str, split: str = "val"):
    """
    Load best.pt for run 'tag' (e.g., 'y8s_640') and evaluate on 'val' or 'test'.
    Saves results under runs/detect/<tag>_<split> and prints summary metrics.
    """
    # NOTE: Ultralytics default run path includes 'detect'
    run = WORKDIR / "runs" / tag
    best = run / "weights" / "best.pt"
    assert best.exists(), f"best.pt not found at {best}"

    # infer imgsz from tag suffix, fallback to 640
    try:
        imgsz = int(tag.split("_")[-1])
    except Exception:
        imgsz = 896

    model = YOLO(str(best))
    metrics = model.val(
        data=str(DATA_YAML),
        split=split,          # <-- 'val' or 'test'
        imgsz=imgsz,
        batch=16,
        workers=4,
        project=str(WORKDIR / "runs"),   # Ultralytics will place under runs/detect/
        name=f"{tag}_{split}",           # e.g., y8s_640_val or y8s_640_test
        device=device,
    )

    # evaluation folder Ultralytics just wrote into
    eval_dir = Path(metrics.save_dir)

    # print macro metrics from in-memory object
    print(f"[{tag} | {split.upper()}] "
          f"mAP50-95={metrics.box.map:.3f}  mAP50={metrics.box.map50:.3f}  "
          f"P={metrics.box.mp:.3f}  R={metrics.box.mr:.3f}")

    # optional per-class table (if CSV present)
    df_eval = load_per_class_df(eval_dir)
    if df_eval is not None:
        df = df_eval.rename(columns={
            "ap50": "AP@0.5", "ap50_95": "AP@0.5:0.95",
            "ap": "AP@0.5:0.95", "ap_50_95": "AP@0.5:0.95"
        })
        macro_50   = df["AP@0.5"].mean()      if "AP@0.5" in df else np.nan
        macro_5095 = df["AP@0.5:0.95"].mean() if "AP@0.5:0.95" in df else np.nan
        print(f"[{tag} | {split.upper()}] Macro AP@0.5={macro_50:.3f} | Macro AP@[.5:.95]={macro_5095:.3f}")
        if "class" in df and {"AP@0.5","AP@0.5:0.95"}.issubset(df.columns):
            display(df[["class","AP@0.5","AP@0.5:0.95"]].head())
        else:
            display(df.head())
    else:
        print(f"[{tag} | {split.upper()}] Per-class CSV not found; see plots under: {eval_dir}")

# %%
# VAL
summarize_run("y8s_1024", split="val")
summarize_run("y8m_896", split="val")

# TEST
summarize_run("y8s_1024", split="test")
summarize_run("y8m_896", split="test")
# Out:
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 178.1±19.6 MB/s, size: 120.0 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/val.cache... 408 images, 116 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 408/408 532.1Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.8it/s 14.1s0.4s
#                    all        408        292      0.305      0.181      0.216     0.0987
#                class_1         47         47     0.0756     0.0851     0.0911     0.0237
#                class_2         30         30          0          0     0.0865     0.0241
#                class_3         31         31          1          0      0.286     0.0844
#                class_6         21         21      0.296      0.429      0.382      0.153
#                class_7         32         32      0.111     0.0625     0.0795     0.0254
#               class_16         71         71      0.246      0.324      0.204     0.0959
#               class_17         20         20       0.71       0.55       0.56      0.369
#               class_20         40         40          0          0     0.0386     0.0141
# Speed: 5.2ms preprocess, 23.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8s_1024_val2
# [y8s_1024 | VAL] mAP50-95=0.099  mAP50=0.216  P=0.305  R=0.181
# [y8s_1024 | VAL] Per-class CSV not found; see plots under: /kaggle/working/yolo_patches/runs/y8s_1024_val2
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,845,550 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 179.1±59.2 MB/s, size: 137.1 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/val.cache... 408 images, 116 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 408/408 652.2Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 26/26 1.2it/s 22.0s0.8ss
#                    all        408        292      0.553      0.294      0.305      0.163
#                class_1         47         47      0.205      0.255      0.107     0.0342
#                class_2         30         30      0.494        0.3      0.368      0.173
#                class_3         31         31          1      0.395      0.493      0.298
#                class_6         21         21       0.87      0.286      0.345      0.201
#                class_7         32         32      0.399     0.0625     0.0932     0.0342
#               class_16         71         71      0.392      0.338      0.334      0.161
#               class_17         20         20      0.503       0.65      0.597      0.358
#               class_20         40         40      0.562     0.0656      0.099     0.0429
# Speed: 3.5ms preprocess, 45.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8m_896_val
# [y8m_896 | VAL] mAP50-95=0.163  mAP50=0.305  P=0.553  R=0.294
# [y8m_896 | VAL] Per-class CSV not found; see plots under: /kaggle/working/yolo_patches/runs/y8m_896_val
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 19.6±1.9 MB/s, size: 130.8 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/test... 425 images, 121 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 425/425 420.3it/s 1.0s.1s
# val: New cache created: /kaggle/working/yolo_patches/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 1.8it/s 15.3s0.5s
#                    all        425        304      0.125      0.265      0.126     0.0495
#                class_1         23         23          0          0     0.0115    0.00412
#                class_2         10         10     0.0269        0.1     0.0172    0.00727
#                class_3         26         26      0.133     0.0769     0.0501     0.0213
#                class_6         40         40      0.204      0.575       0.17     0.0369
#               class_16         48         48      0.173      0.562      0.267       0.11
#               class_17        105        105      0.312      0.314       0.32      0.144
#               class_18         42         42      0.065     0.0952      0.102     0.0312
#               class_20         10         10      0.083        0.4     0.0688      0.041
# Speed: 4.8ms preprocess, 25.0ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8s_1024_test
# [y8s_1024 | TEST] mAP50-95=0.049  mAP50=0.126  P=0.125  R=0.265
# [y8s_1024 | TEST] Per-class CSV not found; see plots under: /kaggle/working/yolo_patches/runs/y8s_1024_test
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,845,550 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 196.8±29.0 MB/s, size: 136.2 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/test.cache... 425 images, 121 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 425/425 590.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 1.1it/s 23.7s0.8ss
#                    all        425        304      0.337      0.396      0.281       0.13
#                class_1         23         23     0.0268     0.0435     0.0104    0.00281
#                class_2         10         10       0.12        0.2     0.0741     0.0463
#                class_3         26         26      0.445      0.493      0.384       0.19
#                class_6         40         40      0.381        0.7      0.525      0.213
#               class_16         48         48       0.39      0.625      0.435      0.197
#               class_17        105        105      0.536       0.39      0.403      0.177
#               class_18         42         42      0.431      0.119       0.11     0.0447
#               class_20         10         10      0.368        0.6       0.31      0.167
# Speed: 3.5ms preprocess, 47.5ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/yolo_patches/runs/y8m_896_test
# [y8m_896 | TEST] mAP50-95=0.130  mAP50=0.281  P=0.337  R=0.396
# [y8m_896 | TEST] Per-class CSV not found; see plots under: /kaggle/working/yolo_patches/runs/y8m_896_test

# %%
from pathlib import Path

def find_run_dir(tag: str) -> Path:
    candidates = [
        WORKDIR / "runs" / tag,                  # when you set project=...
        WORKDIR / "runs" / "detect" / tag        # Ultralytics default
    ]
    for d in candidates:
        if (d / "weights" / "best.pt").exists():
            return d
    raise FileNotFoundError(f"best.pt not found under any known path for tag '{tag}'. Tried: " +
                            ", ".join(str(c / 'weights' / 'best.pt') for c in candidates))

best_tag = "y8m_896"  # or "y8s_640"
best_dir = find_run_dir(best_tag)
best_weights = best_dir / "weights" / "best.pt"
model_best = YOLO(str(best_weights))

# 👇 add these lines
from pathlib import Path
TEST_DIR = WORKDIR / "images" / "test"
test_imgs = sorted(TEST_DIR.glob("*.*"))[:12]

pred_out = WORKDIR / "preds" / best_tag
pred_out.mkdir(parents=True, exist_ok=True)

_ = model_best.predict(
    source=[str(p) for p in test_imgs],
    imgsz=int(best_tag.split("_")[-1]),
    conf=0.25,                       # or use best-F1 conf from the sweep below
    iou=0.50,                        # ← 0.45–0.50 typically boosts recall
    project=str(pred_out),
    name="demo",
    save=True
)
print("Saved overlays under:", pred_out / "demo")
# Out:
# 0: 896x896 1 class_3, 43.5ms
# 1: 896x896 (no detections), 43.5ms
# 2: 896x896 1 class_6, 43.5ms
# 3: 896x896 1 class_17, 43.5ms
# 4: 896x896 (no detections), 43.5ms
# 5: 896x896 1 class_3, 1 class_17, 43.5ms
# 6: 896x896 1 class_16, 43.5ms
# 7: 896x896 1 class_16, 43.5ms
# 8: 896x896 1 class_17, 43.5ms
# 9: 896x896 2 class_6s, 43.5ms
# 10: 896x896 1 class_16, 43.5ms
# 11: 896x896 (no detections), 43.5ms
# Speed: 4.0ms preprocess, 43.5ms inference, 0.7ms postprocess per image at shape (1, 3, 896, 896)
# Results saved to /kaggle/working/yolo_patches/preds/y8m_896/demo
# Saved overlays under: /kaggle/working/yolo_patches/preds/y8m_896/demo

# %% [markdown]
# ## Evaluate best.pt on TEST for both models

# %%
# Evaluate best.pt for both runs on the TEST split
RUNS = WORKDIR / "runs"

best_1024 = YOLO(RUNS / "y8s_1024" / "weights" / "best.pt")
best_896 = YOLO(RUNS / "y8m_896" / "weights" / "best.pt")

m1024 = best_1024.val(data=str(DATA_YAML), split="test")
m896 = best_896.val(data=str(DATA_YAML), split="test")

print("[1024] mAP50-95:", m1024.box.map, " mAP50:", m1024.box.map50, " P:", m1024.box.mp, " R:", m1024.box.mr)
print("[896] mAP50-95:", m896.box.map, " mAP50:", m896.box.map50, " P:", m896.box.mp, " R:", m896.box.mr)
# Out:
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 202.8±79.4 MB/s, size: 124.4 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/test.cache... 425 images, 121 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 425/425 611.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 1.8it/s 14.7s0.5s
#                    all        425        304      0.125      0.265      0.126     0.0495
#                class_1         23         23          0          0     0.0115    0.00412
#                class_2         10         10     0.0269        0.1     0.0172    0.00727
#                class_3         26         26      0.133     0.0769     0.0501     0.0213
#                class_6         40         40      0.204      0.575       0.17     0.0369
#               class_16         48         48      0.173      0.562      0.267       0.11
#               class_17        105        105      0.312      0.314       0.32      0.144
#               class_18         42         42      0.065     0.0952      0.102     0.0312
#               class_20         10         10      0.083        0.4     0.0688      0.041
# Speed: 4.6ms preprocess, 23.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val
# Ultralytics 8.3.231 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,845,550 parameters, 0 gradients, 78.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 196.3±74.6 MB/s, size: 129.5 KB)
# val: Scanning /kaggle/working/yolo_patches/labels/test.cache... 425 images, 121 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 425/425 445.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 1.2it/s 23.2s0.8ss
#                    all        425        304      0.337      0.396      0.281       0.13
#                class_1         23         23     0.0268     0.0435     0.0104    0.00281
#                class_2         10         10       0.12        0.2     0.0741     0.0463
#                class_3         26         26      0.445      0.493      0.384       0.19
#                class_6         40         40      0.381        0.7      0.525      0.213
#               class_16         48         48       0.39      0.625      0.435      0.197
#               class_17        105        105      0.536       0.39      0.403      0.177
#               class_18         42         42      0.431      0.119       0.11     0.0447
#               class_20         10         10      0.368        0.6       0.31      0.167
# Speed: 3.9ms preprocess, 46.4ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /kaggle/working/runs/detect/val2
# [1024] mAP50-95: 0.04947902055596225  mAP50: 0.12588586518635037  P: 0.1245990854954693  R: 0.2654933608058608
# [896] mAP50-95: 0.12977813357665485  mAP50: 0.28141060496047066  P: 0.3371700847012319  R: 0.3963605079922198

# %% [markdown]
# ## Prediction TEST for both Models

# %%
# Save predictions for visual inspection (both models)
TEST_DIR = WORKDIR / "images" / "test"

preds_1024 = best_1024.predict(
    source=str(TEST_DIR), imgsz=1024, conf=0.25,
    save=True, project=str(RUNS), name="pred_test_1024"
)
preds_896 = best_896.predict(
    source=str(TEST_DIR), imgsz=896, conf=0.25,
    save=True, project=str(RUNS), name="pred_test_896"
)

print("Saved 1024 preds to:", preds_1024[0].save_dir)
print("Saved 896 preds to:", preds_896[0].save_dir)
# Out:
# image 1/425 /kaggle/working/yolo_patches/images/test/patch_000012.png: 1024x1024 1 class_1, 32.7ms
# image 2/425 /kaggle/working/yolo_patches/images/test/patch_000015.png: 1024x1024 (no detections), 32.7ms
# image 3/425 /kaggle/working/yolo_patches/images/test/patch_000027.png: 1024x1024 1 class_6, 32.2ms
# image 4/425 /kaggle/working/yolo_patches/images/test/patch_000051.png: 1024x1024 1 class_6, 23.1ms
# image 5/425 /kaggle/working/yolo_patches/images/test/patch_000085.png: 1024x1024 1 class_2, 1 class_16, 23.1ms
# image 6/425 /kaggle/working/yolo_patches/images/test/patch_000086.png: 1024x1024 2 class_16s, 23.0ms
# image 7/425 /kaggle/working/yolo_patches/images/test/patch_000096.png: 1024x1024 (no detections), 22.6ms
# image 8/425 /kaggle/working/yolo_patches/images/test/patch_000105.png: 1024x1024 1 class_6, 1 class_20, 22.6ms
# image 9/425 /kaggle/working/yolo_patches/images/test/patch_000123.png: 1024x1024 (no detections), 21.2ms
# image 10/425 /kaggle/working/yolo_patches/images/test/patch_000128.png: 1024x1024 3 class_6s, 19.3ms
# image 11/425 /kaggle/working/yolo_patches/images/test/patch_000132.png: 1024x1024 1 class_2, 2 class_16s, 1 class_17, 19.3ms
# image 12/425 /kaggle/working/yolo_patches/images/test/patch_000134.png: 1024x1024 (no detections), 18.2ms
# image 13/425 /kaggle/working/yolo_patches/images/test/patch_000136.png: 1024x1024 1 class_16, 1 class_17, 20.6ms
# image 14/425 /kaggle/working/yolo_patches/images/test/patch_000140.png: 1024x1024 (no detections), 19.3ms
# image 15/425 /kaggle/working/yolo_patches/images/test/patch_000141.png: 1024x1024 1 class_17, 21.0ms
# image 16/425 /kaggle/working/yolo_patches/images/test/patch_000146.png: 1024x1024 1 class_17, 19.6ms
# image 17/425 /kaggle/working/yolo_patches/images/test/patch_000149.png: 1024x1024 2 class_17s, 19.0ms
# image 18/425 /kaggle/working/yolo_patches/images/test/patch_000164.png: 1024x1024 3 class_18s, 20.0ms
# image 19/425 /kaggle/working/yolo_patches/images/test/patch_000167.png: 1024x1024 2 class_6s, 18.7ms
# image 20/425 /kaggle/working/yolo_patches/images/test/patch_000168.png: 1024x1024 2 class_16s, 1 class_17, 20.4ms
# image 21/425 /kaggle/working/yolo_patches/images/test/patch_000169.png: 1024x1024 2 class_16s, 1 class_20, 19.5ms
# image 22/425 /kaggle/working/yolo_patches/images/test/patch_000170.png: 1024x1024 2 class_16s, 1 class_17, 19.4ms
# image 23/425 /kaggle/working/yolo_patches/images/test/patch_000172.png: 1024x1024 1 class_20, 19.8ms
# image 24/425 /kaggle/working/yolo_patches/images/test/patch_000176.png: 1024x1024 1 class_17, 18.5ms
# image 25/425 /kaggle/working/yolo_patches/images/test/patch_000178.png: 1024x1024 2 class_16s, 1 class_20, 20.3ms
# image 26/425 /kaggle/working/yolo_patches/images/test/patch_000179.png: 1024x1024 1 class_16, 1 class_17, 19.2ms
# image 27/425 /kaggle/working/yolo_patches/images/test/patch_000180.png: 1024x1024 2 class_6s, 18.6ms
# image 28/425 /kaggle/working/yolo_patches/images/test/patch_000197.png: 1024x1024 3 class_16s, 20.7ms
# image 29/425 /kaggle/working/yolo_patches/images/test/patch_000202.png: 1024x1024 1 class_17, 19.0ms
# image 30/425 /kaggle/working/yolo_patches/images/test/patch_000203.png: 1024x1024 (no detections), 19.4ms
# image 31/425 /kaggle/working/yolo_patches/images/test/patch_000213.png: 1024x1024 (no detections), 19.6ms
# image 32/425 /kaggle/working/yolo_patches/images/test/patch_000221.png: 1024x1024 (no detections), 19.8ms
# image 33/425 /kaggle/working/yolo_patches/images/test/patch_000222.png: 1024x1024 1 class_17, 20.0ms
# image 34/425 /kaggle/working/yolo_patches/images/test/patch_000233.png: 1024x1024 (no detections), 19.3ms
# image 35/425 /kaggle/working/yolo_patches/images/test/patch_000239.png: 1024x1024 1 class_18, 19.6ms
# image 36/425 /kaggle/working/yolo_patches/images/test/patch_000269.png: 1024x1024 1 class_17, 19.3ms
# image 37/425 /kaggle/working/yolo_patches/images/test/patch_000278.png: 1024x1024 (no detections), 20.3ms
# image 38/425 /kaggle/working/yolo_patches/images/test/patch_000317.png: 1024x1024 3 class_16s, 19.0ms
# image 39/425 /kaggle/working/yolo_patches/images/test/patch_000332.png: 1024x1024 (no detections), 20.5ms
# image 40/425 /kaggle/working/yolo_patches/images/test/patch_000340.png: 1024x1024 1 class_6, 1 class_17, 18.9ms
# image 41/425 /kaggle/working/yolo_patches/images/test/patch_000366.png: 1024x1024 2 class_6s, 21.3ms
# image 42/425 /kaggle/working/yolo_patches/images/test/patch_000401.png: 1024x1024 1 class_17, 19.8ms
# image 43/425 /kaggle/working/yolo_patches/images/test/patch_000409.png: 1024x1024 1 class_6, 19.9ms
# image 44/425 /kaggle/working/yolo_patches/images/test/patch_000411.png: 1024x1024 1 class_1, 19.5ms
# image 45/425 /kaggle/working/yolo_patches/images/test/patch_000417.png: 1024x1024 (no detections), 19.4ms
# image 46/425 /kaggle/working/yolo_patches/images/test/patch_000439.png: 1024x1024 1 class_16, 19.9ms
# image 47/425 /kaggle/working/yolo_patches/images/test/patch_000446.png: 1024x1024 2 class_6s, 19.1ms
# image 48/425 /kaggle/working/yolo_patches/images/test/patch_000461.png: 1024x1024 1 class_18, 20.1ms
# image 49/425 /kaggle/working/yolo_patches/images/test/patch_000472.png: 1024x1024 2 class_17s, 18.9ms
# image 50/425 /kaggle/working/yolo_patches/images/test/patch_000473.png: 1024x1024 1 class_1, 1 class_16, 20.9ms
# image 51/425 /kaggle/working/yolo_patches/images/test/patch_000478.png: 1024x1024 1 class_6, 19.5ms
# image 52/425 /kaggle/working/yolo_patches/images/test/patch_000489.png: 1024x1024 2 class_6s, 19.5ms
# image 53/425 /kaggle/working/yolo_patches/images/test/patch_000491.png: 1024x1024 1 class_1, 19.3ms
# image 54/425 /kaggle/working/yolo_patches/images/test/patch_000527.png: 1024x1024 3 class_16s, 18.7ms
# image 55/425 /kaggle/working/yolo_patches/images/test/patch_000537.png: 1024x1024 1 class_6, 20.5ms
# image 56/425 /kaggle/working/yolo_patches/images/test/patch_000562.png: 1024x1024 (no detections), 19.0ms
# image 57/425 /kaggle/working/yolo_patches/images/test/patch_000575.png: 1024x1024 (no detections), 21.1ms
# image 58/425 /kaggle/working/yolo_patches/images/test/patch_000595.png: 1024x1024 (no detections), 19.5ms
# image 59/425 /kaggle/working/yolo_patches/images/test/patch_000602.png: 1024x1024 1 class_6, 1 class_18, 20.7ms
# image 60/425 /kaggle/working/yolo_patches/images/test/patch_000612.png: 1024x1024 4 class_16s, 19.5ms
# image 61/425 /kaggle/working/yolo_patches/images/test/patch_000623.png: 1024x1024 (no detections), 19.9ms
# image 62/425 /kaggle/working/yolo_patches/images/test/patch_000632.png: 1024x1024 1 class_6, 20.4ms
# image 63/425 /kaggle/working/yolo_patches/images/test/patch_000635.png: 1024x1024 1 class_17, 19.2ms
# image 64/425 /kaggle/working/yolo_patches/images/test/patch_000643.png: 1024x1024 3 class_16s, 21.4ms
# image 65/425 /kaggle/working/yolo_patches/images/test/patch_000644.png: 1024x1024 1 class_16, 1 class_17, 19.5ms
# image 66/425 /kaggle/working/yolo_patches/images/test/patch_000654.png: 1024x1024 1 class_6, 20.5ms
# image 67/425 /kaggle/working/yolo_patches/images/test/patch_000662.png: 1024x1024 (no detections), 19.8ms
# image 68/425 /kaggle/working/yolo_patches/images/test/patch_000667.png: 1024x1024 1 class_18, 19.8ms
# image 69/425 /kaggle/working/yolo_patches/images/test/patch_000668.png: 1024x1024 1 class_17, 19.8ms
# image 70/425 /kaggle/working/yolo_patches/images/test/patch_000671.png: 1024x1024 1 class_18, 18.4ms
# image 71/425 /kaggle/working/yolo_patches/images/test/patch_000682.png: 1024x1024 (no detections), 20.6ms
# image 72/425 /kaggle/working/yolo_patches/images/test/patch_000687.png: 1024x1024 1 class_17, 19.4ms
# image 73/425 /kaggle/working/yolo_patches/images/test/patch_000688.png: 1024x1024 3 class_18s, 20.2ms
# image 74/425 /kaggle/working/yolo_patches/images/test/patch_000698.png: 1024x1024 (no detections), 19.6ms
# image 75/425 /kaggle/working/yolo_patches/images/test/patch_000703.png: 1024x1024 2 class_16s, 1 class_17, 18.7ms
# image 76/425 /kaggle/working/yolo_patches/images/test/patch_000715.png: 1024x1024 1 class_6, 20.6ms
# image 77/425 /kaggle/working/yolo_patches/images/test/patch_000732.png: 1024x1024 1 class_17, 19.1ms
# image 78/425 /kaggle/working/yolo_patches/images/test/patch_000749.png: 1024x1024 1 class_17, 20.3ms
# image 79/425 /kaggle/working/yolo_patches/images/test/patch_000752.png: 1024x1024 4 class_6s, 19.6ms
# image 80/425 /kaggle/working/yolo_patches/images/test/patch_000754.png: 1024x1024 1 class_17, 18.6ms
# image 81/425 /kaggle/working/yolo_patches/images/test/patch_000755.png: 1024x1024 (no detections), 20.9ms
# image 82/425 /kaggle/working/yolo_patches/images/test/patch_000756.png: 1024x1024 1 class_16, 1 class_18, 19.5ms
# image 83/425 /kaggle/working/yolo_patches/images/test/patch_000757.png: 1024x1024 1 class_17, 20.1ms
# image 84/425 /kaggle/working/yolo_patches/images/test/patch_000761.png: 1024x1024 3 class_18s, 19.9ms
# image 85/425 /kaggle/working/yolo_patches/images/test/patch_000772.png: 1024x1024 1 class_18, 18.6ms
# image 86/425 /kaggle/working/yolo_patches/images/test/patch_000783.png: 1024x1024 1 class_6, 20.8ms
# image 87/425 /kaggle/working/yolo_patches/images/test/patch_000800.png: 1024x1024 1 class_6, 19.8ms
# image 88/425 /kaggle/working/yolo_patches/images/test/patch_000804.png: 1024x1024 1 class_16, 2 class_17s, 19.3ms
# image 89/425 /kaggle/working/yolo_patches/images/test/patch_000814.png: 1024x1024 1 class_6, 20.3ms
# image 90/425 /kaggle/working/yolo_patches/images/test/patch_000815.png: 1024x1024 (no detections), 18.9ms
# image 91/425 /kaggle/working/yolo_patches/images/test/patch_000821.png: 1024x1024 1 class_16, 4 class_18s, 21.4ms
# image 92/425 /kaggle/working/yolo_patches/images/test/patch_000823.png: 1024x1024 1 class_16, 2 class_17s, 1 class_20, 19.7ms
# image 93/425 /kaggle/working/yolo_patches/images/test/patch_000834.png: 1024x1024 1 class_16, 19.6ms
# image 94/425 /kaggle/working/yolo_patches/images/test/patch_000837.png: 1024x1024 (no detections), 19.8ms
# image 95/425 /kaggle/working/yolo_patches/images/test/patch_000851.png: 1024x1024 1 class_17, 18.8ms
# image 96/425 /kaggle/working/yolo_patches/images/test/patch_000867.png: 1024x1024 2 class_17s, 20.3ms
# image 97/425 /kaggle/working/yolo_patches/images/test/patch_000871.png: 1024x1024 3 class_16s, 18.9ms
# image 98/425 /kaggle/working/yolo_patches/images/test/patch_000872.png: 1024x1024 1 class_3, 1 class_16, 1 class_20, 21.2ms
# image 99/425 /kaggle/working/yolo_patches/images/test/patch_000877.png: 1024x1024 1 class_16, 1 class_18, 19.8ms
# image 100/425 /kaggle/working/yolo_patches/images/test/patch_000896.png: 1024x1024 1 class_1, 2 class_16s, 19.3ms
# image 101/425 /kaggle/working/yolo_patches/images/test/patch_000899.png: 1024x1024 (no detections), 20.4ms
# image 102/425 /kaggle/working/yolo_patches/images/test/patch_000902.png: 1024x1024 (no detections), 19.2ms
# image 103/425 /kaggle/working/yolo_patches/images/test/patch_000907.png: 1024x1024 2 class_18s, 21.6ms
# image 104/425 /kaggle/working/yolo_patches/images/test/patch_000924.png: 1024x1024 (no detections), 19.8ms
# image 105/425 /kaggle/working/yolo_patches/images/test/patch_000934.png: 1024x1024 1 class_2, 20.2ms
# image 106/425 /kaggle/working/yolo_patches/images/test/patch_000947.png: 1024x1024 1 class_1, 19.6ms
# image 107/425 /kaggle/working/yolo_patches/images/test/patch_000951.png: 1024x1024 1 class_16, 19.1ms
# image 108/425 /kaggle/working/yolo_patches/images/test/patch_000955.png: 1024x1024 2 class_16s, 1 class_17, 20.0ms
# image 109/425 /kaggle/working/yolo_patches/images/test/patch_000960.png: 1024x1024 1 class_2, 3 class_16s, 18.7ms
# image 110/425 /kaggle/working/yolo_patches/images/test/patch_000962.png: 1024x1024 (no detections), 20.2ms
# image 111/425 /kaggle/working/yolo_patches/images/test/patch_001000.png: 1024x1024 1 class_16, 1 class_18, 19.8ms
# image 112/425 /kaggle/working/yolo_patches/images/test/patch_001015.png: 1024x1024 3 class_16s, 19.5ms
# image 113/425 /kaggle/working/yolo_patches/images/test/patch_001016.png: 1024x1024 2 class_17s, 19.8ms
# image 114/425 /kaggle/working/yolo_patches/images/test/patch_001025.png: 1024x1024 1 class_16, 18.9ms
# image 115/425 /kaggle/working/yolo_patches/images/test/patch_001035.png: 1024x1024 (no detections), 21.1ms
# image 116/425 /kaggle/working/yolo_patches/images/test/patch_001037.png: 1024x1024 1 class_16, 19.5ms
# image 117/425 /kaggle/working/yolo_patches/images/test/patch_001049.png: 1024x1024 1 class_17, 20.4ms
# image 118/425 /kaggle/working/yolo_patches/images/test/patch_001052.png: 1024x1024 4 class_16s, 20.1ms
# image 119/425 /kaggle/working/yolo_patches/images/test/patch_001055.png: 1024x1024 2 class_16s, 1 class_17, 1 class_20, 18.7ms
# image 120/425 /kaggle/working/yolo_patches/images/test/patch_001056.png: 1024x1024 1 class_1, 1 class_3, 20.7ms
# image 121/425 /kaggle/working/yolo_patches/images/test/patch_001065.png: 1024x1024 2 class_16s, 1 class_17, 19.8ms
# image 122/425 /kaggle/working/yolo_patches/images/test/patch_001076.png: 1024x1024 2 class_1s, 18.8ms
# image 123/425 /kaggle/working/yolo_patches/images/test/patch_001088.png: 1024x1024 (no detections), 20.8ms
# image 124/425 /kaggle/working/yolo_patches/images/test/patch_001091.png: 1024x1024 1 class_17, 19.6ms
# image 125/425 /kaggle/working/yolo_patches/images/test/patch_001095.png: 1024x1024 3 class_1s, 20.9ms
# image 126/425 /kaggle/working/yolo_patches/images/test/patch_001100.png: 1024x1024 1 class_6, 19.5ms
# image 127/425 /kaggle/working/yolo_patches/images/test/patch_001105.png: 1024x1024 1 class_6, 19.1ms
# image 128/425 /kaggle/working/yolo_patches/images/test/patch_001116.png: 1024x1024 2 class_6s, 20.0ms
# image 129/425 /kaggle/working/yolo_patches/images/test/patch_001124.png: 1024x1024 3 class_18s, 18.7ms
# image 130/425 /kaggle/working/yolo_patches/images/test/patch_001125.png: 1024x1024 1 class_6, 21.0ms
# image 131/425 /kaggle/working/yolo_patches/images/test/patch_001131.png: 1024x1024 3 class_6s, 19.7ms
# image 132/425 /kaggle/working/yolo_patches/images/test/patch_001142.png: 1024x1024 (no detections), 19.4ms
# image 133/425 /kaggle/working/yolo_patches/images/test/patch_001149.png: 1024x1024 (no detections), 19.8ms
# image 134/425 /kaggle/working/yolo_patches/images/test/patch_001190.png: 1024x1024 3 class_6s, 20.1ms
# image 135/425 /kaggle/working/yolo_patches/images/test/patch_001194.png: 1024x1024 (no detections), 20.3ms
# image 136/425 /kaggle/working/yolo_patches/images/test/patch_001234.png: 1024x1024 3 class_18s, 19.2ms
# image 137/425 /kaggle/working/yolo_patches/images/test/patch_001236.png: 1024x1024 2 class_6s, 1 class_20, 19.9ms
# image 138/425 /kaggle/working/yolo_patches/images/test/patch_001255.png: 1024x1024 1 class_17, 18.7ms
# image 139/425 /kaggle/working/yolo_patches/images/test/patch_001261.png: 1024x1024 2 class_6s, 21.0ms
# image 140/425 /kaggle/working/yolo_patches/images/test/patch_001270.png: 1024x1024 (no detections), 19.8ms
# image 141/425 /kaggle/working/yolo_patches/images/test/patch_001273.png: 1024x1024 3 class_16s, 1 class_17, 19.9ms
# image 142/425 /kaggle/working/yolo_patches/images/test/patch_001287.png: 1024x1024 1 class_6, 19.8ms
# image 143/425 /kaggle/working/yolo_patches/images/test/patch_001304.png: 1024x1024 (no detections), 18.7ms
# image 144/425 /kaggle/working/yolo_patches/images/test/patch_001308.png: 1024x1024 2 class_16s, 20.7ms
# image 145/425 /kaggle/working/yolo_patches/images/test/patch_001333.png: 1024x1024 (no detections), 19.1ms
# image 146/425 /kaggle/working/yolo_patches/images/test/patch_001346.png: 1024x1024 1 class_6, 21.4ms
# image 147/425 /kaggle/working/yolo_patches/images/test/patch_001350.png: 1024x1024 (no detections), 19.5ms
# image 148/425 /kaggle/working/yolo_patches/images/test/patch_001367.png: 1024x1024 1 class_6, 20.6ms
# image 149/425 /kaggle/working/yolo_patches/images/test/patch_001369.png: 1024x1024 1 class_6, 19.7ms
# image 150/425 /kaggle/working/yolo_patches/images/test/patch_001390.png: 1024x1024 1 class_17, 19.7ms
# image 151/425 /kaggle/working/yolo_patches/images/test/patch_001413.png: 1024x1024 1 class_16, 1 class_18, 19.6ms
# image 152/425 /kaggle/working/yolo_patches/images/test/patch_001433.png: 1024x1024 1 class_18, 18.9ms
# image 153/425 /kaggle/working/yolo_patches/images/test/patch_001454.png: 1024x1024 1 class_6, 20.5ms
# image 154/425 /kaggle/working/yolo_patches/images/test/patch_001459.png: 1024x1024 (no detections), 19.0ms
# image 155/425 /kaggle/working/yolo_patches/images/test/patch_001469.png: 1024x1024 1 class_1, 21.2ms
# image 156/425 /kaggle/working/yolo_patches/images/test/patch_001477.png: 1024x1024 1 class_16, 19.7ms
# image 157/425 /kaggle/working/yolo_patches/images/test/patch_001480.png: 1024x1024 (no detections), 21.0ms
# image 158/425 /kaggle/working/yolo_patches/images/test/patch_001498.png: 1024x1024 1 class_6, 19.7ms
# image 159/425 /kaggle/working/yolo_patches/images/test/patch_001505.png: 1024x1024 2 class_6s, 20.2ms
# image 160/425 /kaggle/working/yolo_patches/images/test/patch_001510.png: 1024x1024 2 class_16s, 19.6ms
# image 161/425 /kaggle/working/yolo_patches/images/test/patch_001517.png: 1024x1024 (no detections), 18.7ms
# image 162/425 /kaggle/working/yolo_patches/images/test/patch_001519.png: 1024x1024 1 class_6, 20.3ms
# image 163/425 /kaggle/working/yolo_patches/images/test/patch_001522.png: 1024x1024 2 class_16s, 2 class_17s, 19.1ms
# image 164/425 /kaggle/working/yolo_patches/images/test/patch_001529.png: 1024x1024 1 class_6, 1 class_20, 21.3ms
# image 165/425 /kaggle/working/yolo_patches/images/test/patch_001531.png: 1024x1024 4 class_18s, 19.7ms
# image 166/425 /kaggle/working/yolo_patches/images/test/patch_001540.png: 1024x1024 (no detections), 20.4ms
# image 167/425 /kaggle/working/yolo_patches/images/test/patch_001541.png: 1024x1024 2 class_17s, 20.1ms
# image 168/425 /kaggle/working/yolo_patches/images/test/patch_001548.png: 1024x1024 1 class_17, 19.8ms
# image 169/425 /kaggle/working/yolo_patches/images/test/patch_001579.png: 1024x1024 1 class_16, 1 class_17, 20.5ms
# image 170/425 /kaggle/working/yolo_patches/images/test/patch_001581.png: 1024x1024 2 class_16s, 18.9ms
# image 171/425 /kaggle/working/yolo_patches/images/test/patch_001585.png: 1024x1024 1 class_16, 21.0ms
# image 172/425 /kaggle/working/yolo_patches/images/test/patch_001602.png: 1024x1024 1 class_16, 1 class_20, 19.5ms
# image 173/425 /kaggle/working/yolo_patches/images/test/patch_001605.png: 1024x1024 1 class_17, 19.7ms
# image 174/425 /kaggle/working/yolo_patches/images/test/patch_001617.png: 1024x1024 (no detections), 19.6ms
# image 175/425 /kaggle/working/yolo_patches/images/test/patch_001620.png: 1024x1024 (no detections), 19.4ms
# image 176/425 /kaggle/working/yolo_patches/images/test/patch_001622.png: 1024x1024 (no detections), 19.7ms
# image 177/425 /kaggle/working/yolo_patches/images/test/patch_001625.png: 1024x1024 1 class_1, 1 class_3, 18.7ms
# image 178/425 /kaggle/working/yolo_patches/images/test/patch_001650.png: 1024x1024 1 class_6, 21.0ms
# image 179/425 /kaggle/working/yolo_patches/images/test/patch_001654.png: 1024x1024 (no detections), 19.5ms
# image 180/425 /kaggle/working/yolo_patches/images/test/patch_001679.png: 1024x1024 (no detections), 20.1ms
# image 181/425 /kaggle/working/yolo_patches/images/test/patch_001685.png: 1024x1024 1 class_6, 19.5ms
# image 182/425 /kaggle/working/yolo_patches/images/test/patch_001692.png: 1024x1024 1 class_1, 2 class_16s, 20.7ms
# image 183/425 /kaggle/working/yolo_patches/images/test/patch_001701.png: 1024x1024 (no detections), 20.3ms
# image 184/425 /kaggle/working/yolo_patches/images/test/patch_001705.png: 1024x1024 1 class_16, 18.9ms
# image 185/425 /kaggle/working/yolo_patches/images/test/patch_001715.png: 1024x1024 (no detections), 20.5ms
# image 186/425 /kaggle/working/yolo_patches/images/test/patch_001721.png: 1024x1024 1 class_1, 1 class_3, 2 class_16s, 19.0ms
# image 187/425 /kaggle/working/yolo_patches/images/test/patch_001732.png: 1024x1024 1 class_16, 20.7ms
# image 188/425 /kaggle/working/yolo_patches/images/test/patch_001734.png: 1024x1024 (no detections), 19.2ms
# image 189/425 /kaggle/working/yolo_patches/images/test/patch_001751.png: 1024x1024 1 class_6, 21.2ms
# image 190/425 /kaggle/working/yolo_patches/images/test/patch_001760.png: 1024x1024 1 class_16, 1 class_17, 19.7ms
# image 191/425 /kaggle/working/yolo_patches/images/test/patch_001765.png: 1024x1024 (no detections), 20.6ms
# image 192/425 /kaggle/working/yolo_patches/images/test/patch_001791.png: 1024x1024 (no detections), 19.5ms
# image 193/425 /kaggle/working/yolo_patches/images/test/patch_001796.png: 1024x1024 1 class_1, 1 class_16, 20.9ms
# image 194/425 /kaggle/working/yolo_patches/images/test/patch_001803.png: 1024x1024 1 class_7, 20.0ms
# image 195/425 /kaggle/working/yolo_patches/images/test/patch_001809.png: 1024x1024 1 class_2, 19.4ms
# image 196/425 /kaggle/working/yolo_patches/images/test/patch_001823.png: 1024x1024 2 class_6s, 20.0ms
# image 197/425 /kaggle/working/yolo_patches/images/test/patch_001841.png: 1024x1024 1 class_17, 18.7ms
# image 198/425 /kaggle/working/yolo_patches/images/test/patch_001869.png: 1024x1024 1 class_16, 21.5ms
# image 199/425 /kaggle/working/yolo_patches/images/test/patch_001878.png: 1024x1024 1 class_17, 19.7ms
# image 200/425 /kaggle/working/yolo_patches/images/test/patch_001902.png: 1024x1024 2 class_1s, 20.3ms
# image 201/425 /kaggle/working/yolo_patches/images/test/patch_001904.png: 1024x1024 2 class_16s, 19.7ms
# image 202/425 /kaggle/working/yolo_patches/images/test/patch_001917.png: 1024x1024 3 class_6s, 18.8ms
# image 203/425 /kaggle/working/yolo_patches/images/test/patch_001933.png: 1024x1024 1 class_16, 21.4ms
# image 204/425 /kaggle/working/yolo_patches/images/test/patch_001953.png: 1024x1024 4 class_18s, 19.8ms
# image 205/425 /kaggle/working/yolo_patches/images/test/patch_001957.png: 1024x1024 (no detections), 20.1ms
# image 206/425 /kaggle/working/yolo_patches/images/test/patch_001984.png: 1024x1024 3 class_18s, 20.1ms
# image 207/425 /kaggle/working/yolo_patches/images/test/patch_001988.png: 1024x1024 1 class_16, 4 class_18s, 19.0ms
# image 208/425 /kaggle/working/yolo_patches/images/test/patch_001992.png: 1024x1024 1 class_16, 20.3ms
# image 209/425 /kaggle/working/yolo_patches/images/test/patch_001996.png: 1024x1024 1 class_2, 1 class_16, 18.8ms
# image 210/425 /kaggle/working/yolo_patches/images/test/patch_001997.png: 1024x1024 1 class_6, 21.2ms
# image 211/425 /kaggle/working/yolo_patches/images/test/patch_002020.png: 1024x1024 (no detections), 20.0ms
# image 212/425 /kaggle/working/yolo_patches/images/test/patch_002024.png: 1024x1024 1 class_17, 21.3ms
# image 213/425 /kaggle/working/yolo_patches/images/test/patch_002064.png: 1024x1024 1 class_6, 20.7ms
# image 214/425 /kaggle/working/yolo_patches/images/test/patch_002090.png: 1024x1024 1 class_16, 1 class_18, 19.2ms
# image 215/425 /kaggle/working/yolo_patches/images/test/patch_002101.png: 1024x1024 (no detections), 20.5ms
# image 216/425 /kaggle/working/yolo_patches/images/test/patch_002109.png: 1024x1024 1 class_16, 19.1ms
# image 217/425 /kaggle/working/yolo_patches/images/test/patch_002116.png: 1024x1024 1 class_17, 21.2ms
# image 218/425 /kaggle/working/yolo_patches/images/test/patch_002137.png: 1024x1024 (no detections), 19.5ms
# image 219/425 /kaggle/working/yolo_patches/images/test/patch_002143.png: 1024x1024 2 class_16s, 20.8ms
# image 220/425 /kaggle/working/yolo_patches/images/test/patch_002151.png: 1024x1024 2 class_6s, 19.9ms
# image 221/425 /kaggle/working/yolo_patches/images/test/patch_002155.png: 1024x1024 1 class_3, 1 class_16, 1 class_20, 19.4ms
# image 222/425 /kaggle/working/yolo_patches/images/test/patch_002173.png: 1024x1024 1 class_7, 19.9ms
# image 223/425 /kaggle/working/yolo_patches/images/test/patch_002191.png: 1024x1024 2 class_16s, 2 class_17s, 18.8ms
# image 224/425 /kaggle/working/yolo_patches/images/test/patch_002192.png: 1024x1024 1 class_6, 21.0ms
# image 225/425 /kaggle/working/yolo_patches/images/test/patch_002208.png: 1024x1024 (no detections), 19.8ms
# image 226/425 /kaggle/working/yolo_patches/images/test/patch_002226.png: 1024x1024 2 class_16s, 20.7ms
# image 227/425 /kaggle/working/yolo_patches/images/test/patch_002231.png: 1024x1024 (no detections), 19.9ms
# image 228/425 /kaggle/working/yolo_patches/images/test/patch_002243.png: 1024x1024 1 class_17, 20.0ms
# image 229/425 /kaggle/working/yolo_patches/images/test/patch_002247.png: 1024x1024 (no detections), 20.5ms
# image 230/425 /kaggle/working/yolo_patches/images/test/patch_002249.png: 1024x1024 2 class_6s, 19.0ms
# image 231/425 /kaggle/working/yolo_patches/images/test/patch_002259.png: 1024x1024 2 class_6s, 20.8ms
# image 232/425 /kaggle/working/yolo_patches/images/test/patch_002287.png: 1024x1024 (no detections), 19.2ms
# image 233/425 /kaggle/working/yolo_patches/images/test/patch_002289.png: 1024x1024 1 class_6, 21.0ms
# image 234/425 /kaggle/working/yolo_patches/images/test/patch_002301.png: 1024x1024 1 class_6, 19.7ms
# image 235/425 /kaggle/working/yolo_patches/images/test/patch_002303.png: 1024x1024 1 class_17, 20.2ms
# image 236/425 /kaggle/working/yolo_patches/images/test/patch_002307.png: 1024x1024 2 class_16s, 20.1ms
# image 237/425 /kaggle/working/yolo_patches/images/test/patch_002308.png: 1024x1024 2 class_16s, 1 class_17, 18.8ms
# image 238/425 /kaggle/working/yolo_patches/images/test/patch_002320.png: 1024x1024 1 class_3, 1 class_20, 21.0ms
# image 239/425 /kaggle/working/yolo_patches/images/test/patch_002327.png: 1024x1024 1 class_17, 19.8ms
# image 240/425 /kaggle/working/yolo_patches/images/test/patch_002342.png: 1024x1024 (no detections), 20.2ms
# image 241/425 /kaggle/working/yolo_patches/images/test/patch_002347.png: 1024x1024 1 class_17, 20.6ms
# image 242/425 /kaggle/working/yolo_patches/images/test/patch_002348.png: 1024x1024 1 class_6, 19.0ms
# image 243/425 /kaggle/working/yolo_patches/images/test/patch_002352.png: 1024x1024 2 class_16s, 1 class_17, 21.2ms
# image 244/425 /kaggle/working/yolo_patches/images/test/patch_002357.png: 1024x1024 1 class_16, 1 class_17, 19.8ms
# image 245/425 /kaggle/working/yolo_patches/images/test/patch_002367.png: 1024x1024 3 class_17s, 19.5ms
# image 246/425 /kaggle/working/yolo_patches/images/test/patch_002368.png: 1024x1024 2 class_1s, 20.5ms
# image 247/425 /kaggle/working/yolo_patches/images/test/patch_002387.png: 1024x1024 3 class_6s, 18.9ms
# image 248/425 /kaggle/working/yolo_patches/images/test/patch_002406.png: 1024x1024 3 class_18s, 21.0ms
# image 249/425 /kaggle/working/yolo_patches/images/test/patch_002438.png: 1024x1024 1 class_17, 19.7ms
# image 250/425 /kaggle/working/yolo_patches/images/test/patch_002444.png: 1024x1024 2 class_17s, 19.6ms
# image 251/425 /kaggle/working/yolo_patches/images/test/patch_002449.png: 1024x1024 2 class_16s, 20.2ms
# image 252/425 /kaggle/working/yolo_patches/images/test/patch_002460.png: 1024x1024 1 class_7, 1 class_20, 18.7ms
# image 253/425 /kaggle/working/yolo_patches/images/test/patch_002461.png: 1024x1024 (no detections), 21.0ms
# image 254/425 /kaggle/working/yolo_patches/images/test/patch_002465.png: 1024x1024 1 class_6, 19.5ms
# image 255/425 /kaggle/working/yolo_patches/images/test/patch_002468.png: 1024x1024 1 class_6, 21.5ms
# image 256/425 /kaggle/working/yolo_patches/images/test/patch_002488.png: 1024x1024 2 class_16s, 1 class_17, 1 class_20, 19.8ms
# image 257/425 /kaggle/working/yolo_patches/images/test/patch_002494.png: 1024x1024 (no detections), 19.2ms
# image 258/425 /kaggle/working/yolo_patches/images/test/patch_002522.png: 1024x1024 1 class_7, 1 class_16, 1 class_18, 20.3ms
# image 259/425 /kaggle/working/yolo_patches/images/test/patch_002527.png: 1024x1024 3 class_16s, 18.8ms
# image 260/425 /kaggle/working/yolo_patches/images/test/patch_002531.png: 1024x1024 1 class_17, 20.4ms
# image 261/425 /kaggle/working/yolo_patches/images/test/patch_002532.png: 1024x1024 2 class_16s, 2 class_17s, 20.3ms
# image 262/425 /kaggle/working/yolo_patches/images/test/patch_002548.png: 1024x1024 3 class_18s, 18.7ms
# image 263/425 /kaggle/working/yolo_patches/images/test/patch_002550.png: 1024x1024 1 class_17, 20.3ms
# image 264/425 /kaggle/working/yolo_patches/images/test/patch_002556.png: 1024x1024 (no detections), 19.4ms
# image 265/425 /kaggle/working/yolo_patches/images/test/patch_002559.png: 1024x1024 (no detections), 18.3ms
# image 266/425 /kaggle/working/yolo_patches/images/test/patch_002568.png: 1024x1024 (no detections), 20.6ms
# image 267/425 /kaggle/working/yolo_patches/images/test/patch_002589.png: 1024x1024 1 class_7, 3 class_18s, 19.2ms
# image 268/425 /kaggle/working/yolo_patches/images/test/patch_002597.png: 1024x1024 2 class_1s, 21.6ms
# image 269/425 /kaggle/working/yolo_patches/images/test/patch_002618.png: 1024x1024 1 class_7, 3 class_18s, 19.8ms
# image 270/425 /kaggle/working/yolo_patches/images/test/patch_002624.png: 1024x1024 3 class_6s, 18.5ms
# image 271/425 /kaggle/working/yolo_patches/images/test/patch_002646.png: 1024x1024 3 class_6s, 19.3ms
# image 272/425 /kaggle/working/yolo_patches/images/test/patch_002660.png: 1024x1024 1 class_6, 20.1ms
# image 273/425 /kaggle/working/yolo_patches/images/test/patch_002673.png: 1024x1024 (no detections), 19.0ms
# image 274/425 /kaggle/working/yolo_patches/images/test/patch_002680.png: 1024x1024 (no detections), 21.1ms
# image 275/425 /kaggle/working/yolo_patches/images/test/patch_002683.png: 1024x1024 1 class_17, 19.7ms
# image 276/425 /kaggle/working/yolo_patches/images/test/patch_002694.png: 1024x1024 2 class_16s, 21.1ms
# image 277/425 /kaggle/working/yolo_patches/images/test/patch_002700.png: 1024x1024 (no detections), 19.8ms
# image 278/425 /kaggle/working/yolo_patches/images/test/patch_002724.png: 1024x1024 (no detections), 19.8ms
# image 279/425 /kaggle/working/yolo_patches/images/test/patch_002739.png: 1024x1024 (no detections), 19.9ms
# image 280/425 /kaggle/working/yolo_patches/images/test/patch_002753.png: 1024x1024 (no detections), 20.0ms
# image 281/425 /kaggle/working/yolo_patches/images/test/patch_002773.png: 1024x1024 (no detections), 19.5ms
# image 282/425 /kaggle/working/yolo_patches/images/test/patch_002774.png: 1024x1024 2 class_16s, 20.5ms
# image 283/425 /kaggle/working/yolo_patches/images/test/patch_002787.png: 1024x1024 1 class_17, 1 class_20, 20.0ms
# image 284/425 /kaggle/working/yolo_patches/images/test/patch_002790.png: 1024x1024 1 class_16, 1 class_18, 18.9ms
# image 285/425 /kaggle/working/yolo_patches/images/test/patch_002803.png: 1024x1024 (no detections), 20.2ms
# image 286/425 /kaggle/working/yolo_patches/images/test/patch_002815.png: 1024x1024 1 class_6, 19.0ms
# image 287/425 /kaggle/working/yolo_patches/images/test/patch_002818.png: 1024x1024 (no detections), 21.2ms
# image 288/425 /kaggle/working/yolo_patches/images/test/patch_002855.png: 1024x1024 2 class_6s, 19.6ms
# image 289/425 /kaggle/working/yolo_patches/images/test/patch_002870.png: 1024x1024 1 class_17, 20.8ms
# image 290/425 /kaggle/working/yolo_patches/images/test/patch_002875.png: 1024x1024 1 class_3, 19.5ms
# image 291/425 /kaggle/working/yolo_patches/images/test/patch_002880.png: 1024x1024 1 class_6, 20.0ms
# image 292/425 /kaggle/working/yolo_patches/images/test/patch_002887.png: 1024x1024 2 class_16s, 1 class_17, 20.4ms
# image 293/425 /kaggle/working/yolo_patches/images/test/patch_002892.png: 1024x1024 1 class_16, 1 class_18, 19.3ms
# image 294/425 /kaggle/working/yolo_patches/images/test/patch_002893.png: 1024x1024 1 class_18, 21.1ms
# image 295/425 /kaggle/working/yolo_patches/images/test/patch_002894.png: 1024x1024 1 class_1, 19.4ms
# image 296/425 /kaggle/working/yolo_patches/images/test/patch_002901.png: 1024x1024 3 class_18s, 20.7ms
# image 297/425 /kaggle/working/yolo_patches/images/test/patch_002911.png: 1024x1024 1 class_1, 19.8ms
# image 298/425 /kaggle/working/yolo_patches/images/test/patch_002934.png: 1024x1024 3 class_18s, 19.8ms
# image 299/425 /kaggle/working/yolo_patches/images/test/patch_002947.png: 1024x1024 3 class_18s, 20.5ms
# image 300/425 /kaggle/working/yolo_patches/images/test/patch_002949.png: 1024x1024 1 class_17, 18.9ms
# image 301/425 /kaggle/working/yolo_patches/images/test/patch_002953.png: 1024x1024 1 class_16, 20.5ms
# image 302/425 /kaggle/working/yolo_patches/images/test/patch_002964.png: 1024x1024 3 class_18s, 19.5ms
# image 303/425 /kaggle/working/yolo_patches/images/test/patch_002974.png: 1024x1024 2 class_1s, 19.8ms
# image 304/425 /kaggle/working/yolo_patches/images/test/patch_002983.png: 1024x1024 (no detections), 20.9ms
# image 305/425 /kaggle/working/yolo_patches/images/test/patch_003007.png: 1024x1024 1 class_16, 19.1ms
# image 306/425 /kaggle/working/yolo_patches/images/test/patch_003026.png: 1024x1024 1 class_16, 21.6ms
# image 307/425 /kaggle/working/yolo_patches/images/test/patch_003032.png: 1024x1024 (no detections), 19.8ms
# image 308/425 /kaggle/working/yolo_patches/images/test/patch_003048.png: 1024x1024 (no detections), 19.9ms
# image 309/425 /kaggle/working/yolo_patches/images/test/patch_003054.png: 1024x1024 (no detections), 19.5ms
# image 310/425 /kaggle/working/yolo_patches/images/test/patch_003064.png: 1024x1024 (no detections), 20.3ms
# image 311/425 /kaggle/working/yolo_patches/images/test/patch_003084.png: 1024x1024 (no detections), 20.3ms
# image 312/425 /kaggle/working/yolo_patches/images/test/patch_003085.png: 1024x1024 2 class_1s, 20.3ms
# image 313/425 /kaggle/working/yolo_patches/images/test/patch_003100.png: 1024x1024 (no detections), 19.0ms
# image 314/425 /kaggle/working/yolo_patches/images/test/patch_003107.png: 1024x1024 (no detections), 18.4ms
# image 315/425 /kaggle/working/yolo_patches/images/test/patch_003112.png: 1024x1024 1 class_20, 20.4ms
# image 316/425 /kaggle/working/yolo_patches/images/test/patch_003116.png: 1024x1024 1 class_20, 19.8ms
# image 317/425 /kaggle/working/yolo_patches/images/test/patch_003137.png: 1024x1024 (no detections), 19.9ms
# image 318/425 /kaggle/working/yolo_patches/images/test/patch_003140.png: 1024x1024 (no detections), 20.4ms
# image 319/425 /kaggle/working/yolo_patches/images/test/patch_003145.png: 1024x1024 1 class_7, 19.8ms
# image 320/425 /kaggle/working/yolo_patches/images/test/patch_003146.png: 1024x1024 (no detections), 20.2ms
# image 321/425 /kaggle/working/yolo_patches/images/test/patch_003175.png: 1024x1024 (no detections), 19.2ms
# image 322/425 /kaggle/working/yolo_patches/images/test/patch_003179.png: 1024x1024 (no detections), 19.9ms
# image 323/425 /kaggle/working/yolo_patches/images/test/patch_003181.png: 1024x1024 (no detections), 19.5ms
# image 324/425 /kaggle/working/yolo_patches/images/test/patch_003192.png: 1024x1024 (no detections), 20.7ms
# image 325/425 /kaggle/working/yolo_patches/images/test/patch_003199.png: 1024x1024 (no detections), 20.3ms
# image 326/425 /kaggle/working/yolo_patches/images/test/patch_003221.png: 1024x1024 1 class_17, 1 class_18, 20.2ms
# image 327/425 /kaggle/working/yolo_patches/images/test/patch_003258.png: 1024x1024 (no detections), 20.0ms
# image 328/425 /kaggle/working/yolo_patches/images/test/patch_003260.png: 1024x1024 (no detections), 19.4ms
# image 329/425 /kaggle/working/yolo_patches/images/test/patch_003261.png: 1024x1024 (no detections), 20.4ms
# image 330/425 /kaggle/working/yolo_patches/images/test/patch_003265.png: 1024x1024 (no detections), 19.3ms
# image 331/425 /kaggle/working/yolo_patches/images/test/patch_003268.png: 1024x1024 (no detections), 20.9ms
# image 332/425 /kaggle/working/yolo_patches/images/test/patch_003270.png: 1024x1024 (no detections), 19.4ms
# image 333/425 /kaggle/working/yolo_patches/images/test/patch_003284.png: 1024x1024 (no detections), 21.4ms
# image 334/425 /kaggle/working/yolo_patches/images/test/patch_003286.png: 1024x1024 (no detections), 19.4ms
# image 335/425 /kaggle/working/yolo_patches/images/test/patch_003304.png: 1024x1024 (no detections), 21.4ms
# image 336/425 /kaggle/working/yolo_patches/images/test/patch_003307.png: 1024x1024 (no detections), 19.8ms
# image 337/425 /kaggle/working/yolo_patches/images/test/patch_003353.png: 1024x1024 (no detections), 20.4ms
# image 338/425 /kaggle/working/yolo_patches/images/test/patch_003360.png: 1024x1024 (no detections), 19.5ms
# image 339/425 /kaggle/working/yolo_patches/images/test/patch_003428.png: 1024x1024 (no detections), 20.5ms
# image 340/425 /kaggle/working/yolo_patches/images/test/patch_003457.png: 1024x1024 (no detections), 19.8ms
# image 341/425 /kaggle/working/yolo_patches/images/test/patch_003460.png: 1024x1024 (no detections), 20.5ms
# image 342/425 /kaggle/working/yolo_patches/images/test/patch_003479.png: 1024x1024 (no detections), 19.7ms
# image 343/425 /kaggle/working/yolo_patches/images/test/patch_003484.png: 1024x1024 (no detections), 20.9ms
# image 344/425 /kaggle/working/yolo_patches/images/test/patch_003491.png: 1024x1024 (no detections), 20.4ms
# image 345/425 /kaggle/working/yolo_patches/images/test/patch_003493.png: 1024x1024 (no detections), 18.9ms
# image 346/425 /kaggle/working/yolo_patches/images/test/patch_003494.png: 1024x1024 (no detections), 20.8ms
# image 347/425 /kaggle/working/yolo_patches/images/test/patch_003522.png: 1024x1024 1 class_6, 19.7ms
# image 348/425 /kaggle/working/yolo_patches/images/test/patch_003548.png: 1024x1024 (no detections), 20.0ms
# image 349/425 /kaggle/working/yolo_patches/images/test/patch_003549.png: 1024x1024 1 class_20, 19.8ms
# image 350/425 /kaggle/working/yolo_patches/images/test/patch_003563.png: 1024x1024 (no detections), 19.9ms
# image 351/425 /kaggle/working/yolo_patches/images/test/patch_003565.png: 1024x1024 1 class_18, 20.7ms
# image 352/425 /kaggle/working/yolo_patches/images/test/patch_003568.png: 1024x1024 (no detections), 19.2ms
# image 353/425 /kaggle/working/yolo_patches/images/test/patch_003572.png: 1024x1024 (no detections), 21.0ms
# image 354/425 /kaggle/working/yolo_patches/images/test/patch_003573.png: 1024x1024 1 class_16, 1 class_20, 19.7ms
# image 355/425 /kaggle/working/yolo_patches/images/test/patch_003578.png: 1024x1024 1 class_17, 21.2ms
# image 356/425 /kaggle/working/yolo_patches/images/test/patch_003582.png: 1024x1024 (no detections), 19.5ms
# image 357/425 /kaggle/working/yolo_patches/images/test/patch_003583.png: 1024x1024 (no detections), 20.8ms
# image 358/425 /kaggle/working/yolo_patches/images/test/patch_003605.png: 1024x1024 (no detections), 19.8ms
# image 359/425 /kaggle/working/yolo_patches/images/test/patch_003607.png: 1024x1024 (no detections), 20.8ms
# image 360/425 /kaggle/working/yolo_patches/images/test/patch_003620.png: 1024x1024 (no detections), 20.0ms
# image 361/425 /kaggle/working/yolo_patches/images/test/patch_003631.png: 1024x1024 1 class_18, 20.7ms
# image 362/425 /kaggle/working/yolo_patches/images/test/patch_003645.png: 1024x1024 1 class_6, 20.1ms
# image 363/425 /kaggle/working/yolo_patches/images/test/patch_003650.png: 1024x1024 (no detections), 19.1ms
# image 364/425 /kaggle/working/yolo_patches/images/test/patch_003660.png: 1024x1024 (no detections), 21.6ms
# image 365/425 /kaggle/working/yolo_patches/images/test/patch_003662.png: 1024x1024 (no detections), 19.8ms
# image 366/425 /kaggle/working/yolo_patches/images/test/patch_003663.png: 1024x1024 (no detections), 20.7ms
# image 367/425 /kaggle/working/yolo_patches/images/test/patch_003664.png: 1024x1024 (no detections), 19.7ms
# image 368/425 /kaggle/working/yolo_patches/images/test/patch_003669.png: 1024x1024 (no detections), 21.1ms
# image 369/425 /kaggle/working/yolo_patches/images/test/patch_003684.png: 1024x1024 1 class_17, 20.7ms
# image 370/425 /kaggle/working/yolo_patches/images/test/patch_003699.png: 1024x1024 (no detections), 19.7ms
# image 371/425 /kaggle/working/yolo_patches/images/test/patch_003715.png: 1024x1024 (no detections), 20.7ms
# image 372/425 /kaggle/working/yolo_patches/images/test/patch_003729.png: 1024x1024 (no detections), 19.6ms
# image 373/425 /kaggle/working/yolo_patches/images/test/patch_003732.png: 1024x1024 (no detections), 20.7ms
# image 374/425 /kaggle/working/yolo_patches/images/test/patch_003733.png: 1024x1024 (no detections), 19.9ms
# image 375/425 /kaggle/working/yolo_patches/images/test/patch_003740.png: 1024x1024 (no detections), 21.0ms
# image 376/425 /kaggle/working/yolo_patches/images/test/patch_003747.png: 1024x1024 (no detections), 19.7ms
# image 377/425 /kaggle/working/yolo_patches/images/test/patch_003759.png: 1024x1024 1 class_20, 20.7ms
# image 378/425 /kaggle/working/yolo_patches/images/test/patch_003765.png: 1024x1024 (no detections), 19.6ms
# image 379/425 /kaggle/working/yolo_patches/images/test/patch_003778.png: 1024x1024 (no detections), 21.0ms
# image 380/425 /kaggle/working/yolo_patches/images/test/patch_003789.png: 1024x1024 1 class_16, 19.5ms
# image 381/425 /kaggle/working/yolo_patches/images/test/patch_003802.png: 1024x1024 (no detections), 20.9ms
# image 382/425 /kaggle/working/yolo_patches/images/test/patch_003813.png: 1024x1024 (no detections), 19.6ms
# image 383/425 /kaggle/working/yolo_patches/images/test/patch_003824.png: 1024x1024 (no detections), 22.1ms
# image 384/425 /kaggle/working/yolo_patches/images/test/patch_003826.png: 1024x1024 (no detections), 20.0ms
# image 385/425 /kaggle/working/yolo_patches/images/test/patch_003830.png: 1024x1024 (no detections), 20.8ms
# image 386/425 /kaggle/working/yolo_patches/images/test/patch_003842.png: 1024x1024 1 class_16, 19.7ms
# image 387/425 /kaggle/working/yolo_patches/images/test/patch_003843.png: 1024x1024 (no detections), 19.9ms
# image 388/425 /kaggle/working/yolo_patches/images/test/patch_003853.png: 1024x1024 (no detections), 19.8ms
# image 389/425 /kaggle/working/yolo_patches/images/test/patch_003869.png: 1024x1024 (no detections), 19.8ms
# image 390/425 /kaggle/working/yolo_patches/images/test/patch_003872.png: 1024x1024 (no detections), 20.3ms
# image 391/425 /kaggle/working/yolo_patches/images/test/patch_003903.png: 1024x1024 (no detections), 19.1ms
# image 392/425 /kaggle/working/yolo_patches/images/test/patch_003904.png: 1024x1024 (no detections), 20.8ms
# image 393/425 /kaggle/working/yolo_patches/images/test/patch_003912.png: 1024x1024 (no detections), 19.9ms
# image 394/425 /kaggle/working/yolo_patches/images/test/patch_003916.png: 1024x1024 1 class_17, 21.3ms
# image 395/425 /kaggle/working/yolo_patches/images/test/patch_003936.png: 1024x1024 (no detections), 19.5ms
# image 396/425 /kaggle/working/yolo_patches/images/test/patch_003949.png: 1024x1024 (no detections), 21.0ms
# image 397/425 /kaggle/working/yolo_patches/images/test/patch_003961.png: 1024x1024 (no detections), 19.7ms
# image 398/425 /kaggle/working/yolo_patches/images/test/patch_003970.png: 1024x1024 1 class_7, 21.4ms
# image 399/425 /kaggle/working/yolo_patches/images/test/patch_004010.png: 1024x1024 (no detections), 19.8ms
# image 400/425 /kaggle/working/yolo_patches/images/test/patch_004011.png: 1024x1024 (no detections), 19.9ms
# image 401/425 /kaggle/working/yolo_patches/images/test/patch_004026.png: 1024x1024 (no detections), 19.8ms
# image 402/425 /kaggle/working/yolo_patches/images/test/patch_004029.png: 1024x1024 1 class_17, 20.5ms
# image 403/425 /kaggle/working/yolo_patches/images/test/patch_004036.png: 1024x1024 1 class_6, 19.8ms
# image 404/425 /kaggle/working/yolo_patches/images/test/patch_004041.png: 1024x1024 (no detections), 19.5ms
# image 405/425 /kaggle/working/yolo_patches/images/test/patch_004060.png: 1024x1024 (no detections), 20.7ms
# image 406/425 /kaggle/working/yolo_patches/images/test/patch_004061.png: 1024x1024 1 class_1, 1 class_17, 19.8ms
# image 407/425 /kaggle/working/yolo_patches/images/test/patch_004062.png: 1024x1024 1 class_6, 20.6ms
# image 408/425 /kaggle/working/yolo_patches/images/test/patch_004063.png: 1024x1024 (no detections), 19.2ms
# image 409/425 /kaggle/working/yolo_patches/images/test/patch_004072.png: 1024x1024 (no detections), 21.2ms
# image 410/425 /kaggle/working/yolo_patches/images/test/patch_004078.png: 1024x1024 1 class_3, 20.0ms
# image 411/425 /kaggle/working/yolo_patches/images/test/patch_004098.png: 1024x1024 1 class_16, 21.4ms
# image 412/425 /kaggle/working/yolo_patches/images/test/patch_004099.png: 1024x1024 1 class_16, 19.8ms
# image 413/425 /kaggle/working/yolo_patches/images/test/patch_004103.png: 1024x1024 1 class_20, 19.3ms
# image 414/425 /kaggle/working/yolo_patches/images/test/patch_004109.png: 1024x1024 (no detections), 20.7ms
# image 415/425 /kaggle/working/yolo_patches/images/test/patch_004119.png: 1024x1024 (no detections), 19.1ms
# image 416/425 /kaggle/working/yolo_patches/images/test/patch_004133.png: 1024x1024 (no detections), 21.3ms
# image 417/425 /kaggle/working/yolo_patches/images/test/patch_004140.png: 1024x1024 (no detections), 19.7ms
# image 418/425 /kaggle/working/yolo_patches/images/test/patch_004147.png: 1024x1024 (no detections), 21.0ms
# image 419/425 /kaggle/working/yolo_patches/images/test/patch_004148.png: 1024x1024 (no detections), 19.7ms
# image 420/425 /kaggle/working/yolo_patches/images/test/patch_004151.png: 1024x1024 (no detections), 21.0ms
# image 421/425 /kaggle/working/yolo_patches/images/test/patch_004156.png: 1024x1024 (no detections), 19.7ms
# image 422/425 /kaggle/working/yolo_patches/images/test/patch_004193.png: 1024x1024 1 class_2, 21.2ms
# image 423/425 /kaggle/working/yolo_patches/images/test/patch_004211.png: 1024x1024 (no detections), 20.7ms
# image 424/425 /kaggle/working/yolo_patches/images/test/patch_004216.png: 1024x1024 (no detections), 20.2ms
# image 425/425 /kaggle/working/yolo_patches/images/test/patch_004217.png: 1024x1024 (no detections), 21.1ms
# Speed: 5.0ms preprocess, 20.1ms inference, 1.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to /kaggle/working/yolo_patches/runs/pred_test_1024
#
# image 1/425 /kaggle/working/yolo_patches/images/test/patch_000012.png: 896x896 2 class_3s, 46.4ms
# image 2/425 /kaggle/working/yolo_patches/images/test/patch_000015.png: 896x896 (no detections), 42.9ms
# image 3/425 /kaggle/working/yolo_patches/images/test/patch_000027.png: 896x896 1 class_6, 41.8ms
# image 4/425 /kaggle/working/yolo_patches/images/test/patch_000051.png: 896x896 1 class_17, 44.0ms
# image 5/425 /kaggle/working/yolo_patches/images/test/patch_000085.png: 896x896 (no detections), 43.1ms
# image 6/425 /kaggle/working/yolo_patches/images/test/patch_000086.png: 896x896 1 class_3, 1 class_17, 42.4ms
# image 7/425 /kaggle/working/yolo_patches/images/test/patch_000096.png: 896x896 1 class_16, 45.5ms
# image 8/425 /kaggle/working/yolo_patches/images/test/patch_000105.png: 896x896 2 class_16s, 43.0ms
# image 9/425 /kaggle/working/yolo_patches/images/test/patch_000123.png: 896x896 1 class_17, 41.7ms
# image 10/425 /kaggle/working/yolo_patches/images/test/patch_000128.png: 896x896 2 class_6s, 43.4ms
# image 11/425 /kaggle/working/yolo_patches/images/test/patch_000132.png: 896x896 1 class_16, 42.6ms
# image 12/425 /kaggle/working/yolo_patches/images/test/patch_000134.png: 896x896 (no detections), 42.0ms
# image 13/425 /kaggle/working/yolo_patches/images/test/patch_000136.png: 896x896 1 class_2, 43.7ms
# image 14/425 /kaggle/working/yolo_patches/images/test/patch_000140.png: 896x896 (no detections), 42.6ms
# image 15/425 /kaggle/working/yolo_patches/images/test/patch_000141.png: 896x896 2 class_17s, 43.1ms
# image 16/425 /kaggle/working/yolo_patches/images/test/patch_000146.png: 896x896 2 class_17s, 40.1ms
# image 17/425 /kaggle/working/yolo_patches/images/test/patch_000149.png: 896x896 2 class_17s, 43.7ms
# image 18/425 /kaggle/working/yolo_patches/images/test/patch_000164.png: 896x896 1 class_16, 42.4ms
# image 19/425 /kaggle/working/yolo_patches/images/test/patch_000167.png: 896x896 1 class_6, 41.0ms
# image 20/425 /kaggle/working/yolo_patches/images/test/patch_000168.png: 896x896 1 class_17, 43.8ms
# image 21/425 /kaggle/working/yolo_patches/images/test/patch_000169.png: 896x896 1 class_1, 42.6ms
# image 22/425 /kaggle/working/yolo_patches/images/test/patch_000170.png: 896x896 (no detections), 41.7ms
# image 23/425 /kaggle/working/yolo_patches/images/test/patch_000172.png: 896x896 1 class_16, 1 class_20, 45.4ms
# image 24/425 /kaggle/working/yolo_patches/images/test/patch_000176.png: 896x896 1 class_17, 42.7ms
# image 25/425 /kaggle/working/yolo_patches/images/test/patch_000178.png: 896x896 1 class_16, 41.8ms
# image 26/425 /kaggle/working/yolo_patches/images/test/patch_000179.png: 896x896 1 class_16, 44.6ms
# image 27/425 /kaggle/working/yolo_patches/images/test/patch_000180.png: 896x896 1 class_6, 43.1ms
# image 28/425 /kaggle/working/yolo_patches/images/test/patch_000197.png: 896x896 2 class_16s, 41.9ms
# image 29/425 /kaggle/working/yolo_patches/images/test/patch_000202.png: 896x896 1 class_17, 44.9ms
# ...
# image 276/425 /kaggle/working/yolo_patches/images/test/patch_002694.png: 896x896 2 class_3s, 1 class_16, 42.6ms
# image 277/425 /kaggle/working/yolo_patches/images/test/patch_002700.png: 896x896 2 class_17s, 42.5ms
# image 278/425 /kaggle/working/yolo_patches/images/test/patch_002724.png: 896x896 1 class_17, 41.0ms
# image 279/425 /kaggle/working/yolo_patches/images/test/patch_002739.png: 896x896 (no detections), 39.6ms
# image 280/425 /kaggle/working/yolo_patches/images/test/patch_002753.png: 896x896 (no detections), 45.0ms
# image 281/425 /kaggle/working/yolo_patches/images/test/patch_002773.png: 896x896 1 class_16, 41.3ms
# image 282/425 /kaggle/working/yolo_patches/images/test/patch_002774.png: 896x896 1 class_1, 1 class_3, 1 class_16, 1 class_17, 43.0ms
# image 283/425 /kaggle/working/yolo_patches/images/test/patch_002787.png: 896x896 2 class_17s, 42.1ms
# image 284/425 /kaggle/working/yolo_patches/images/test/patch_002790.png: 896x896 1 class_2, 1 class_20, 41.4ms
# image 285/425 /kaggle/working/yolo_patches/images/test/patch_002803.png: 896x896 (no detections), 44.3ms
# image 286/425 /kaggle/working/yolo_patches/images/test/patch_002815.png: 896x896 (no detections), 42.3ms
# image 287/425 /kaggle/working/yolo_patches/images/test/patch_002818.png: 896x896 1 class_16, 41.0ms
# image 288/425 /kaggle/working/yolo_patches/images/test/patch_002855.png: 896x896 1 class_17, 43.0ms
# image 289/425 /kaggle/working/yolo_patches/images/test/patch_002870.png: 896x896 2 class_17s, 41.1ms
# image 290/425 /kaggle/working/yolo_patches/images/test/patch_002875.png: 896x896 1 class_2, 44.1ms
# image 291/425 /kaggle/working/yolo_patches/images/test/patch_002880.png: 896x896 3 class_6s, 43.5ms
# image 292/425 /kaggle/working/yolo_patches/images/test/patch_002887.png: 896x896 (no detections), 41.7ms
# image 293/425 /kaggle/working/yolo_patches/images/test/patch_002892.png: 896x896 1 class_3, 44.5ms
# image 294/425 /kaggle/working/yolo_patches/images/test/patch_002893.png: 896x896 1 class_18, 41.7ms
# image 295/425 /kaggle/working/yolo_patches/images/test/patch_002894.png: 896x896 2 class_1s, 1 class_16, 41.3ms
# image 296/425 /kaggle/working/yolo_patches/images/test/patch_002901.png: 896x896 1 class_7, 3 class_18s, 44.5ms
# image 297/425 /kaggle/working/yolo_patches/images/test/patch_002911.png: 896x896 1 class_1, 1 class_16, 42.9ms
# image 298/425 /kaggle/working/yolo_patches/images/test/patch_002934.png: 896x896 1 class_16, 40.7ms
# image 299/425 /kaggle/working/yolo_patches/images/test/patch_002947.png: 896x896 1 class_17, 2 class_18s, 43.6ms
# image 300/425 /kaggle/working/yolo_patches/images/test/patch_002949.png: 896x896 (no detections), 42.3ms
# image 301/425 /kaggle/working/yolo_patches/images/test/patch_002953.png: 896x896 1 class_16, 41.7ms
# image 302/425 /kaggle/working/yolo_patches/images/test/patch_002964.png: 896x896 1 class_16, 43.7ms
# image 303/425 /kaggle/working/yolo_patches/images/test/patch_002974.png: 896x896 1 class_1, 41.8ms
# image 304/425 /kaggle/working/yolo_patches/images/test/patch_002983.png: 896x896 (no detections), 41.3ms
# image 305/425 /kaggle/working/yolo_patches/images/test/patch_003007.png: 896x896 (no detections), 44.6ms
# image 306/425 /kaggle/working/yolo_patches/images/test/patch_003026.png: 896x896 1 class_3, 42.7ms
# image 307/425 /kaggle/working/yolo_patches/images/test/patch_003032.png: 896x896 (no detections), 41.3ms
# image 308/425 /kaggle/working/yolo_patches/images/test/patch_003048.png: 896x896 (no detections), 42.5ms
# image 309/425 /kaggle/working/yolo_patches/images/test/patch_003054.png: 896x896 1 class_17, 42.2ms
# image 310/425 /kaggle/working/yolo_patches/images/test/patch_003064.png: 896x896 (no detections), 44.1ms
# image 311/425 /kaggle/working/yolo_patches/images/test/patch_003084.png: 896x896 (no detections), 42.2ms
# image 312/425 /kaggle/working/yolo_patches/images/test/patch_003085.png: 896x896 (no detections), 42.0ms
# image 313/425 /kaggle/working/yolo_patches/images/test/patch_003100.png: 896x896 (no detections), 43.6ms
# image 314/425 /kaggle/working/yolo_patches/images/test/patch_003107.png: 896x896 (no detections), 41.5ms
# image 315/425 /kaggle/working/yolo_patches/images/test/patch_003112.png: 896x896 1 class_16, 44.6ms
# image 316/425 /kaggle/working/yolo_patches/images/test/patch_003116.png: 896x896 (no detections), 42.5ms
# image 317/425 /kaggle/working/yolo_patches/images/test/patch_003137.png: 896x896 (no detections), 41.2ms
# image 318/425 /kaggle/working/yolo_patches/images/test/patch_003140.png: 896x896 (no detections), 45.2ms
# image 319/425 /kaggle/working/yolo_patches/images/test/patch_003145.png: 896x896 (no detections), 42.1ms
# image 320/425 /kaggle/working/yolo_patches/images/test/patch_003146.png: 896x896 (no detections), 43.7ms
# image 321/425 /kaggle/working/yolo_patches/images/test/patch_003175.png: 896x896 (no detections), 43.1ms
# image 322/425 /kaggle/working/yolo_patches/images/test/patch_003179.png: 896x896 1 class_1, 41.7ms
# image 323/425 /kaggle/working/yolo_patches/images/test/patch_003181.png: 896x896 (no detections), 43.4ms
# image 324/425 /kaggle/working/yolo_patches/images/test/patch_003192.png: 896x896 (no detections), 41.9ms
# image 325/425 /kaggle/working/yolo_patches/images/test/patch_003199.png: 896x896 (no detections), 42.0ms
# image 326/425 /kaggle/working/yolo_patches/images/test/patch_003221.png: 896x896 (no detections), 42.4ms
# image 327/425 /kaggle/working/yolo_patches/images/test/patch_003258.png: 896x896 1 class_17, 41.7ms
# image 328/425 /kaggle/working/yolo_patches/images/test/patch_003260.png: 896x896 (no detections), 44.6ms
# image 329/425 /kaggle/working/yolo_patches/images/test/patch_003261.png: 896x896 (no detections), 43.3ms
# image 330/425 /kaggle/working/yolo_patches/images/test/patch_003265.png: 896x896 (no detections), 42.2ms
# image 331/425 /kaggle/working/yolo_patches/images/test/patch_003268.png: 896x896 (no detections), 44.4ms
# image 332/425 /kaggle/working/yolo_patches/images/test/patch_003270.png: 896x896 (no detections), 41.8ms
# image 333/425 /kaggle/working/yolo_patches/images/test/patch_003284.png: 896x896 1 class_17, 44.3ms
# image 334/425 /kaggle/working/yolo_patches/images/test/patch_003286.png: 896x896 (no detections), 42.2ms
# image 335/425 /kaggle/working/yolo_patches/images/test/patch_003304.png: 896x896 (no detections), 41.9ms
# image 336/425 /kaggle/working/yolo_patches/images/test/patch_003307.png: 896x896 1 class_17, 44.3ms
# image 337/425 /kaggle/working/yolo_patches/images/test/patch_003353.png: 896x896 1 class_1, 40.9ms
# image 338/425 /kaggle/working/yolo_patches/images/test/patch_003360.png: 896x896 (no detections), 41.6ms
# image 339/425 /kaggle/working/yolo_patches/images/test/patch_003428.png: 896x896 (no detections), 43.0ms
# image 340/425 /kaggle/working/yolo_patches/images/test/patch_003457.png: 896x896 (no detections), 41.3ms
# image 341/425 /kaggle/working/yolo_patches/images/test/patch_003460.png: 896x896 (no detections), 44.3ms
# image 342/425 /kaggle/working/yolo_patches/images/test/patch_003479.png: 896x896 (no detections), 41.7ms
# image 343/425 /kaggle/working/yolo_patches/images/test/patch_003484.png: 896x896 (no detections), 42.9ms
# image 344/425 /kaggle/working/yolo_patches/images/test/patch_003491.png: 896x896 (no detections), 42.5ms
# image 345/425 /kaggle/working/yolo_patches/images/test/patch_003493.png: 896x896 (no detections), 42.2ms
# image 346/425 /kaggle/working/yolo_patches/images/test/patch_003494.png: 896x896 1 class_17, 44.8ms
# image 347/425 /kaggle/working/yolo_patches/images/test/patch_003522.png: 896x896 (no detections), 41.1ms
# image 348/425 /kaggle/working/yolo_patches/images/test/patch_003548.png: 896x896 1 class_16, 42.4ms
# image 349/425 /kaggle/working/yolo_patches/images/test/patch_003549.png: 896x896 (no detections), 41.9ms
# image 350/425 /kaggle/working/yolo_patches/images/test/patch_003563.png: 896x896 (no detections), 41.0ms
# image 351/425 /kaggle/working/yolo_patches/images/test/patch_003565.png: 896x896 1 class_18, 43.9ms
# image 352/425 /kaggle/working/yolo_patches/images/test/patch_003568.png: 896x896 (no detections), 41.4ms
# image 353/425 /kaggle/working/yolo_patches/images/test/patch_003572.png: 896x896 (no detections), 43.8ms
# image 354/425 /kaggle/working/yolo_patches/images/test/patch_003573.png: 896x896 1 class_17, 41.8ms
# image 355/425 /kaggle/working/yolo_patches/images/test/patch_003578.png: 896x896 (no detections), 41.4ms
# image 356/425 /kaggle/working/yolo_patches/images/test/patch_003582.png: 896x896 (no detections), 43.4ms
# image 357/425 /kaggle/working/yolo_patches/images/test/patch_003583.png: 896x896 (no detections), 40.9ms
# image 358/425 /kaggle/working/yolo_patches/images/test/patch_003605.png: 896x896 1 class_17, 44.3ms
# image 359/425 /kaggle/working/yolo_patches/images/test/patch_003607.png: 896x896 (no detections), 41.0ms
# image 360/425 /kaggle/working/yolo_patches/images/test/patch_003620.png: 896x896 (no detections), 43.4ms
# image 361/425 /kaggle/working/yolo_patches/images/test/patch_003631.png: 896x896 1 class_17, 42.9ms
# image 362/425 /kaggle/working/yolo_patches/images/test/patch_003645.png: 896x896 1 class_17, 40.7ms
# image 363/425 /kaggle/working/yolo_patches/images/test/patch_003650.png: 896x896 (no detections), 44.2ms
# image 364/425 /kaggle/working/yolo_patches/images/test/patch_003660.png: 896x896 (no detections), 41.5ms
# image 365/425 /kaggle/working/yolo_patches/images/test/patch_003662.png: 896x896 (no detections), 42.9ms
# image 366/425 /kaggle/working/yolo_patches/images/test/patch_003663.png: 896x896 (no detections), 42.9ms
# image 367/425 /kaggle/working/yolo_patches/images/test/patch_003664.png: 896x896 (no detections), 41.2ms
# image 368/425 /kaggle/working/yolo_patches/images/test/patch_003669.png: 896x896 (no detections), 43.8ms
# image 369/425 /kaggle/working/yolo_patches/images/test/patch_003684.png: 896x896 (no detections), 41.6ms
# image 370/425 /kaggle/working/yolo_patches/images/test/patch_003699.png: 896x896 (no detections), 43.7ms
# image 371/425 /kaggle/working/yolo_patches/images/test/patch_003715.png: 896x896 (no detections), 41.3ms
# image 372/425 /kaggle/working/yolo_patches/images/test/patch_003729.png: 896x896 (no detections), 42.7ms
# image 373/425 /kaggle/working/yolo_patches/images/test/patch_003732.png: 896x896 (no detections), 43.7ms
# image 374/425 /kaggle/working/yolo_patches/images/test/patch_003733.png: 896x896 (no detections), 40.9ms
# image 375/425 /kaggle/working/yolo_patches/images/test/patch_003740.png: 896x896 (no detections), 43.7ms
# image 376/425 /kaggle/working/yolo_patches/images/test/patch_003747.png: 896x896 (no detections), 41.9ms
# image 377/425 /kaggle/working/yolo_patches/images/test/patch_003759.png: 896x896 (no detections), 42.6ms
# image 378/425 /kaggle/working/yolo_patches/images/test/patch_003765.png: 896x896 (no detections), 41.9ms
# image 379/425 /kaggle/working/yolo_patches/images/test/patch_003778.png: 896x896 (no detections), 42.4ms
# image 380/425 /kaggle/working/yolo_patches/images/test/patch_003789.png: 896x896 (no detections), 42.9ms
# image 381/425 /kaggle/working/yolo_patches/images/test/patch_003802.png: 896x896 1 class_6, 40.9ms
# image 382/425 /kaggle/working/yolo_patches/images/test/patch_003813.png: 896x896 (no detections), 44.4ms
# image 383/425 /kaggle/working/yolo_patches/images/test/patch_003824.png: 896x896 (no detections), 41.2ms
# image 384/425 /kaggle/working/yolo_patches/images/test/patch_003826.png: 896x896 (no detections), 43.5ms
# image 385/425 /kaggle/working/yolo_patches/images/test/patch_003830.png: 896x896 (no detections), 42.9ms
# image 386/425 /kaggle/working/yolo_patches/images/test/patch_003842.png: 896x896 (no detections), 42.1ms
# image 387/425 /kaggle/working/yolo_patches/images/test/patch_003843.png: 896x896 (no detections), 43.8ms
# image 388/425 /kaggle/working/yolo_patches/images/test/patch_003853.png: 896x896 (no detections), 41.9ms
# image 389/425 /kaggle/working/yolo_patches/images/test/patch_003869.png: 896x896 (no detections), 42.7ms
# image 390/425 /kaggle/working/yolo_patches/images/test/patch_003872.png: 896x896 (no detections), 41.6ms
# image 391/425 /kaggle/working/yolo_patches/images/test/patch_003903.png: 896x896 1 class_1, 40.5ms
# image 392/425 /kaggle/working/yolo_patches/images/test/patch_003904.png: 896x896 (no detections), 44.7ms
# image 393/425 /kaggle/working/yolo_patches/images/test/patch_003912.png: 896x896 (no detections), 41.4ms
# image 394/425 /kaggle/working/yolo_patches/images/test/patch_003916.png: 896x896 1 class_17, 40.8ms
# image 395/425 /kaggle/working/yolo_patches/images/test/patch_003936.png: 896x896 (no detections), 44.2ms
# image 396/425 /kaggle/working/yolo_patches/images/test/patch_003949.png: 896x896 (no detections), 41.7ms
# image 397/425 /kaggle/working/yolo_patches/images/test/patch_003961.png: 896x896 (no detections), 40.3ms
# image 398/425 /kaggle/working/yolo_patches/images/test/patch_003970.png: 896x896 (no detections), 43.1ms
# image 399/425 /kaggle/working/yolo_patches/images/test/patch_004010.png: 896x896 (no detections), 42.7ms
# image 400/425 /kaggle/working/yolo_patches/images/test/patch_004011.png: 896x896 (no detections), 42.0ms
# image 401/425 /kaggle/working/yolo_patches/images/test/patch_004026.png: 896x896 (no detections), 43.5ms
# image 402/425 /kaggle/working/yolo_patches/images/test/patch_004029.png: 896x896 (no detections), 41.1ms
# image 403/425 /kaggle/working/yolo_patches/images/test/patch_004036.png: 896x896 (no detections), 42.5ms
# image 404/425 /kaggle/working/yolo_patches/images/test/patch_004041.png: 896x896 (no detections), 42.7ms
# image 405/425 /kaggle/working/yolo_patches/images/test/patch_004060.png: 896x896 (no detections), 40.9ms
# image 406/425 /kaggle/working/yolo_patches/images/test/patch_004061.png: 896x896 (no detections), 42.7ms
# image 407/425 /kaggle/working/yolo_patches/images/test/patch_004062.png: 896x896 1 class_17, 41.5ms
# image 408/425 /kaggle/working/yolo_patches/images/test/patch_004063.png: 896x896 (no detections), 40.8ms
# image 409/425 /kaggle/working/yolo_patches/images/test/patch_004072.png: 896x896 (no detections), 42.5ms
# image 410/425 /kaggle/working/yolo_patches/images/test/patch_004078.png: 896x896 1 class_17, 42.2ms
# image 411/425 /kaggle/working/yolo_patches/images/test/patch_004098.png: 896x896 (no detections), 40.2ms
# image 412/425 /kaggle/working/yolo_patches/images/test/patch_004099.png: 896x896 1 class_3, 42.6ms
# image 413/425 /kaggle/working/yolo_patches/images/test/patch_004103.png: 896x896 (no detections), 40.6ms
# image 414/425 /kaggle/working/yolo_patches/images/test/patch_004109.png: 896x896 (no detections), 41.2ms
# image 415/425 /kaggle/working/yolo_patches/images/test/patch_004119.png: 896x896 (no detections), 43.3ms
# image 416/425 /kaggle/working/yolo_patches/images/test/patch_004133.png: 896x896 (no detections), 41.7ms
# image 417/425 /kaggle/working/yolo_patches/images/test/patch_004140.png: 896x896 (no detections), 44.3ms
# image 418/425 /kaggle/working/yolo_patches/images/test/patch_004147.png: 896x896 (no detections), 41.4ms
# image 419/425 /kaggle/working/yolo_patches/images/test/patch_004148.png: 896x896 (no detections), 42.7ms
# image 420/425 /kaggle/working/yolo_patches/images/test/patch_004151.png: 896x896 1 class_3, 1 class_17, 42.3ms
# image 421/425 /kaggle/working/yolo_patches/images/test/patch_004156.png: 896x896 1 class_17, 40.5ms
# image 422/425 /kaggle/working/yolo_patches/images/test/patch_004193.png: 896x896 1 class_1, 44.3ms
# image 423/425 /kaggle/working/yolo_patches/images/test/patch_004211.png: 896x896 (no detections), 41.5ms
# image 424/425 /kaggle/working/yolo_patches/images/test/patch_004216.png: 896x896 (no detections), 42.2ms
# image 425/425 /kaggle/working/yolo_patches/images/test/patch_004217.png: 896x896 (no detections), 42.4ms
# Speed: 4.0ms preprocess, 42.7ms inference, 1.3ms postprocess per image at shape (1, 3, 896, 896)
# Results saved to /kaggle/working/yolo_patches/runs/pred_test_896
# Saved 1024 preds to: /kaggle/working/yolo_patches/runs/pred_test_1024
# Saved 896 preds to: /kaggle/working/yolo_patches/runs/pred_test_896

# %% [markdown]
# When evaluating the stronger models on the held-out test split (425 images), the YOLOv8-medium model at 896×896 clearly outperforms the YOLOv8-small model at 1024×1024. The y8m_896 configuration achieves mAP@0.5 = 0.281 and mAP@[0.5:0.95] = 0.130, more than doubling the performance of y8s_1024 (0.126 and 0.049 respectively). Precision and recall also increase substantially (from 0.125→0.337 and 0.265→0.396). Qualitative predictions confirm the quantitative findings: y8m_896 produces consistent detections, while y8s_1024 often fails to detect any objects in scenes containing multiple targets. We therefore select YOLOv8-medium at 896² as the final high-capacity model for this dataset.

# %% [markdown]
# ## “mIoU-style” evaluation for detection

# %%
# Compute mean IoU (of true positives) on TEST for a chosen model
def iou_of(a, b):
    xa1, ya1, xa2, ya2 = a
    xb1, yb1, xb2, yb2 = b
    inter_w = max(0.0, min(xa2, xb2) - max(xa1, xb1))
    inter_h = max(0.0, min(ya2, yb2) - max(ya1, yb1))
    inter = inter_w * inter_h
    area_a = max(0.0, (xa2 - xa1)) * max(0.0, (ya2 - ya1))
    area_b = max(0.0, (xb2 - xb1)) * max(0.0, (yb2 - yb1))
    union = area_a + area_b - inter + 1e-9
    return inter / union

def load_yolo_labels(txt_path):
    boxes, classes = [], []
    if not txt_path.exists():
        return np.zeros((0,4)), np.zeros((0,), dtype=int)
    for line in txt_path.read_text().strip().splitlines():
        parts = line.strip().split()
        if len(parts) != 5: 
            continue
        c, cx, cy, w, h = map(float, parts)
        classes.append(int(c))
        boxes.append([cx, cy, w, h])
    return np.array(boxes, dtype=float), np.array(classes, dtype=int)

def yolo_to_xyxy(norm_boxes, W, H):
    if len(norm_boxes) == 0:
        return np.zeros((0,4))
    cx, cy, w, h = norm_boxes[:,0], norm_boxes[:,1], norm_boxes[:,2], norm_boxes[:,3]
    x1 = (cx - w/2) * W
    y1 = (cy - h/2) * H
    x2 = (cx + w/2) * W
    y2 = (cy + h/2) * H
    return np.stack([x1,y1,x2,y2], axis=1)

def find_best(tag: str):
    """Return Path to best.pt whether it’s under /runs or /runs/detect."""
    candidates = [
        WORKDIR / "runs" / tag / "weights" / "best.pt",
        WORKDIR / "runs" / "detect" / tag / "weights" / "best.pt",
    ]
    for p in candidates:
        if p.exists():
            print("✅ Found best.pt at:", p)
            return p
    raise FileNotFoundError(f"No best.pt found for {tag}. Tried:\n" + "\n".join(str(c) for c in candidates))


tag = "y8m_896"  

best_path = find_best(tag)
model = YOLO(str(best_path))

TEST_IMG_DIR = WORKDIR / "images" / "test"
TEST_LBL_DIR = WORKDIR / "labels" / "test"

# Run predictions (no saving, only boxes)
preds = model.predict(
    source=str(TEST_IMG_DIR),
    imgsz=int(tag.split("_")[-1]),
    conf=0.25,
    iou=0.5,
    save=False,
    verbose=False
)

# --------------------------------
# Compute mean IoU per class
all_ious, per_class_ious = [], {}

for r in preds:
    im_path = Path(r.path)
    W, H = r.orig_shape[1], r.orig_shape[0]

    # Ground truth
    gt_txt = TEST_LBL_DIR / (im_path.stem + ".txt")
    gt_norm, gt_cls = load_yolo_labels(gt_txt)
    gt_xyxy = yolo_to_xyxy(gt_norm, W, H)

    # Predictions
    if r.boxes is None or len(r.boxes) == 0:
        continue
    p_xyxy = r.boxes.xyxy.cpu().numpy()
    p_cls = r.boxes.cls.cpu().numpy().astype(int)
    p_conf = r.boxes.conf.cpu().numpy()

    used_gt = set()
    order = np.argsort(-p_conf)  # sort by confidence desc
    for idx in order:
        pc = p_cls[idx]
        pb = p_xyxy[idx]
        # candidate GTs of same class not yet matched
        candidates = [j for j, gc in enumerate(gt_cls) if gc == pc and j not in used_gt]
        if not candidates:
            continue
        ious = [iou_of(pb, gt_xyxy[j]) for j in candidates]
        j_best = candidates[int(np.argmax(ious))]
        iou = ious[int(np.argmax(ious))]
        if iou >= 0.5:  # count as true positive
            used_gt.add(j_best)
            all_ious.append(iou)
            per_class_ious.setdefault(pc, []).append(iou)

# --------------------------------
def mean_or_nan(lst): 
    return float(np.mean(lst)) if lst else float("nan")

print(f"[{tag}] TP mean IoU@matched (≥0.5): {mean_or_nan(all_ious):.3f}  (n={len(all_ious)})")
for c, vals in sorted(per_class_ious.items()):
    print(f"  class {c}: mIoU={mean_or_nan(vals):.3f}  n={len(vals)}")
# Out:
# ✅ Found best.pt at: /kaggle/working/yolo_patches/runs/y8m_896/weights/best.pt
# [y8m_896] TP mean IoU@matched (≥0.5): 0.700  (n=96)
#   class 3: mIoU=0.673  n=9
#   class 4: mIoU=0.698  n=21
#   class 6: mIoU=0.725  n=25
#   class 7: mIoU=0.698  n=37
#   class 8: mIoU=0.636  n=3
#   class 9: mIoU=0.632  n=1

# %% [markdown]
# Although the y8m_896 model exhibits a slightly lower mean IoU over true positives (0.70 vs. 0.73 for y8s_896), it produces substantially more true positives (96 vs. 77) and achieves higher mAP and recall. This indicates that the medium model successfully detects additional, harder objects with IoUs just above the 0.5 threshold, slightly reducing the average IoU but improving overall detection performance. Therefore, the medium model is strictly better in terms of coverage and mAP, while maintaining strong localization quality.

# %%
# Compute mean IoU (of true positives) on TEST for a chosen model
def iou_of(a, b):
    xa1, ya1, xa2, ya2 = a
    xb1, yb1, xb2, yb2 = b
    inter_w = max(0.0, min(xa2, xb2) - max(xa1, xb1))
    inter_h = max(0.0, min(ya2, yb2) - max(ya1, yb1))
    inter = inter_w * inter_h
    area_a = max(0.0, (xa2 - xa1)) * max(0.0, (ya2 - ya1))
    area_b = max(0.0, (xb2 - xb1)) * max(0.0, (yb2 - yb1))
    union = area_a + area_b - inter + 1e-9
    return inter / union

def load_yolo_labels(txt_path):
    boxes, classes = [], []
    if not txt_path.exists():
        return np.zeros((0,4)), np.zeros((0,), dtype=int)
    for line in txt_path.read_text().strip().splitlines():
        parts = line.strip().split()
        if len(parts) != 5: 
            continue
        c, cx, cy, w, h = map(float, parts)
        classes.append(int(c))
        boxes.append([cx, cy, w, h])
    return np.array(boxes, dtype=float), np.array(classes, dtype=int)

def yolo_to_xyxy(norm_boxes, W, H):
    if len(norm_boxes) == 0:
        return np.zeros((0,4))
    cx, cy, w, h = norm_boxes[:,0], norm_boxes[:,1], norm_boxes[:,2], norm_boxes[:,3]
    x1 = (cx - w/2) * W
    y1 = (cy - h/2) * H
    x2 = (cx + w/2) * W
    y2 = (cy + h/2) * H
    return np.stack([x1,y1,x2,y2], axis=1)

def find_best(tag: str):
    """Return Path to best.pt whether it’s under /runs or /runs/detect."""
    candidates = [
        WORKDIR / "runs" / tag / "weights" / "best.pt",
        WORKDIR / "runs" / "detect" / tag / "weights" / "best.pt",
    ]
    for p in candidates:
        if p.exists():
            print("✅ Found best.pt at:", p)
            return p
    raise FileNotFoundError(f"No best.pt found for {tag}. Tried:\n" + "\n".join(str(c) for c in candidates))


tag = "y8s_1024" 

best_path = find_best(tag)
model = YOLO(str(best_path))

TEST_IMG_DIR = WORKDIR / "images" / "test"
TEST_LBL_DIR = WORKDIR / "labels" / "test"

# Run predictions 
preds = model.predict(
    source=str(TEST_IMG_DIR),
    imgsz=int(tag.split("_")[-1]),
    conf=0.25,
    iou=0.5,
    save=False,
    verbose=False
)

# --------------------------------
# Compute mean IoU per class
all_ious, per_class_ious = [], {}

for r in preds:
    im_path = Path(r.path)
    W, H = r.orig_shape[1], r.orig_shape[0]

    # Ground truth
    gt_txt = TEST_LBL_DIR / (im_path.stem + ".txt")
    gt_norm, gt_cls = load_yolo_labels(gt_txt)
    gt_xyxy = yolo_to_xyxy(gt_norm, W, H)

    # Predictions
    if r.boxes is None or len(r.boxes) == 0:
        continue
    p_xyxy = r.boxes.xyxy.cpu().numpy()
    p_cls = r.boxes.cls.cpu().numpy().astype(int)
    p_conf = r.boxes.conf.cpu().numpy()

    used_gt = set()
    order = np.argsort(-p_conf)  # sort by confidence desc
    for idx in order:
        pc = p_cls[idx]
        pb = p_xyxy[idx]
        # candidate GTs of same class not yet matched
        candidates = [j for j, gc in enumerate(gt_cls) if gc == pc and j not in used_gt]
        if not candidates:
            continue
        ious = [iou_of(pb, gt_xyxy[j]) for j in candidates]
        j_best = candidates[int(np.argmax(ious))]
        iou = ious[int(np.argmax(ious))]
        if iou >= 0.5:  # count as true positive
            used_gt.add(j_best)
            all_ious.append(iou)
            per_class_ious.setdefault(pc, []).append(iou)

# --------------------------------
def mean_or_nan(lst): 
    return float(np.mean(lst)) if lst else float("nan")

print(f"[{tag}] TP mean IoU@matched (≥0.5): {mean_or_nan(all_ious):.3f}  (n={len(all_ious)})")
for c, vals in sorted(per_class_ious.items()):
    print(f"  class {c}: mIoU={mean_or_nan(vals):.3f}  n={len(vals)}")
# Out:
# ✅ Found best.pt at: /kaggle/working/yolo_patches/runs/y8s_1024/weights/best.pt
# [y8s_1024] TP mean IoU@matched (≥0.5): 0.702  (n=59)
#   class 4: mIoU=0.656  n=9
#   class 6: mIoU=0.731  n=18
#   class 7: mIoU=0.721  n=23
#   class 8: mIoU=0.643  n=9
